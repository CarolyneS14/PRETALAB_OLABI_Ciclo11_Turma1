# %% [markdown]
# #Lidando com Arquivos, Pacotes e Módulos

# %% [markdown]
# O objetivo dessa aula é praticar os temas da aula 1 e 2 do módulo 1 e para isso vamos trabalhar com um exemplo de análise de dados usando somente bibliotecas padrão do Python.

# %% [markdown]
# ###Preparando o ambiente

# %%
# Montando o Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# mostra o conteudo do drive
# !ls /content/drive/MyDrive
# Out:
# 'Apresentação - Hipóteses .gslides'   COURSERA				 grande_arquivo.gsheet
# 'Carolyne Oliveira'		      CURRICULUM			 LABORATORIA
#  Certificados			      DESENVOLVE			 PRETALAB
#  Classroom			     'DP - 900'				 REPROGRAMA
# 'Colab Notebooks'		     'experimento_duraccao (1).gsheet'	 UDEMY
# 'Cópia de Exercicio-Segunda.gsheet'   experimento_duraccao.gsheet

# %%
#Acessando a pasta
# %cd /content/drive/MyDrive/PRETALAB/Python/Aula03
# Out:
# /content/drive/MyDrive/PRETALAB/Python/Aula03

# %%
# Mostra o conteudo do local/pasta
# !ls
# Out:
# arquivo_modelo.ipynb	internacoes.csv		   modulo_analise.py	 __pycache__
# internacao2.csv		meu_arquivo.csv		   modulo_internacao.py
# internacao_desafio.csv	modulo_analise_desafio.py  nome_arquivo.csv

# %%
# Biblioteca do python utilizada para acessar o sistema, os arquivos. Ele mostra onde vc esta!
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/PRETALAB/Python/Aula03'

# %%
#Importando as bibliotecas
import pandas as pd

# %% [markdown]
# ###Lidando com Arquivos, Pacotes e Módulos

# %% [markdown]
# ####Cenário

# %% [markdown]
# **Objetivo:** Analisar dados de internações hospitalares, calcular métricas como o custo médio por internação, número de internações por tipo de tratamento, e visualizar a quantidade de internações ao longo do tempo.
#
# **Estrutura do Dataset de Internações Hospitalares**
#
#  - Cada linha no dataset conterá as seguintes colunas:
#
# 1. Data de Internação: A data em que o paciente foi internado.
#
# 2. Tratamento: O tipo de tratamento (ex: "Cirurgia", "Tratamento Intensivo", "Exames", "Fisioterapia").
# 3. Dias de Internação: O número de dias que o paciente ficou internado.
#
# 4. Custo Total: O custo total da internação.
#
# **Passos**
#
# 1. Criar um módulo Python para lidar com o arquivo CSV, cálculos, e manipulação de dados.
#
# 2. Gerar dados fictícios de internações hospitalares.
# 3. Analisar e visualizar os dados sem o uso de bibliotecas externas como pandas, usando apenas bibliotecas nativas do Python.

# %% [markdown]
# ### 1. Manipulando arquivos

# %% [markdown]
# Aqui já começamos manipulando arquivos e construindo o módulo, lembre-se de fazer por parte:

# %%
# Importando os módulos padrão do Python
import csv
import random
from datetime import datetime, timedelta # Importando a biblioteca datetime

# %% [markdown]
# ### 1. Criando um módulo como construtor de dados ficticios e manipulando arquivos:

# %%
cria_arquivo = '''
import csv
import random
from datetime import datetime, timedelta

# Construindo a função
# coloque todo o código que anterior numa função que receba o nome e quantidade de linhas do arquivo com extensão csv
def meu_arquivo(nome_arquivo, num_linhas):
  colunas = ['data_internacao', 'tratamento', 'dias_internacao', 'custo_total']
  tratamento = ['cirurgia', 'tratamento_intensivo', 'exames', 'fisioterapia']
  data_inicial = datetime.now() - timedelta(days=730)

  with open(nome_arquivo, 'w', newline='') as arquivo:
    construtor = csv.writer(arquivo)
    #adicionar a lista criada chamada coluna como cabeçalho do arquivo csv
    construtor.writerow(colunas)

    for _ in range(num_linhas):
      data_internacao = data_inicial + timedelta(days=random.randint(1, 730))
      tratamento = random.choice(tratamento)
      dias_internacao = random.randint(1, 30)
      custo_total = round(random.uniform(100.0, 10000.0), 2)
      construtor.writerow([data_internacao.strftime('%Y-%m-%d'), tratamento, dias_internacao, custo_total])
      '''

  #construindo o arquivo do modulo
with open('modulo_internacao.py', 'w') as arquivo:
    arquivo.write(cria_arquivo)

# %% [markdown]
# ### 2. Criando um módulo de análise

# %%
#Construindo o modulo
conteudo = '''
import csv
import math
from datetime import datetime

# Funcao para carregar arquivos csv
def carregar_dados(nome_arquivo):
  dados = []
  with open(nome_arquivo, 'r') as arquivo:
    leitor = csv.DictReader(arquivo)
    for linha in leitor:
      dados.append(linha)
  return dados
  '''
  #construindo o arquivo do modulo
with open('modulo_analise.py', 'w') as modulo:
    modulo.write(conteudo)

# %% [markdown]
# ### Usando o módulo construido

# %%
# importando o módulo e definindo como mi
import modulo_internacao as mi
import modulo_analise as ma

# %%
#criando o arquivo
mi.meu_arquivo('internacao2.csv', 50000)

# %%
# lendo o arquivo
base = ma.carregar_dados('internacao2.csv')

# %%
base
# Out:
# [{'data_internacao': '2024-06-22',
#   'tratamento': 'fisioterapia',
#   'dias_internacao': '1',
#   'custo_total': '9076.2'},
#  {'data_internacao': '2024-04-26',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '4209.86'},
#  {'data_internacao': '2022-10-18',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '324.41'},
#  {'data_internacao': '2023-08-15',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '7424.93'},
#  {'data_internacao': '2022-12-22',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '4196.8'},
#  {'data_internacao': '2023-05-28',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '5679.96'},
#  {'data_internacao': '2024-01-21',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '8802.42'},
#  {'data_internacao': '2023-08-04',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '432.61'},
#  {'data_internacao': '2022-10-20',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '1036.4'},
#  {'data_internacao': '2024-07-31',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '2149.15'},
#  {'data_internacao': '2024-03-01',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '3155.26'},
#  {'data_internacao': '2023-09-28',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '2131.39'},
#  {'data_internacao': '2023-03-10',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5273.17'},
#  {'data_internacao': '2024-09-26',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '2741.35'},
#  {'data_internacao': '2024-05-01',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '9697.22'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '5968.58'},
#  {'data_internacao': '2024-01-10',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '2636.99'},
#  {'data_internacao': '2022-11-29',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '9441.5'},
#  {'data_internacao': '2024-08-04',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '3096.01'},
#  {'data_internacao': '2023-11-03',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '4161.16'},
#  {'data_internacao': '2024-03-08',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '5520.31'},
#  {'data_internacao': '2023-01-28',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '3979.85'},
#  {'data_internacao': '2023-07-18',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '4342.26'},
#  {'data_internacao': '2023-05-06',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5205.7'},
#  {'data_internacao': '2023-11-11',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '2949.71'},
#  {'data_internacao': '2024-01-08',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '8335.69'},
#  {'data_internacao': '2023-01-12',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '9795.91'},
#  {'data_internacao': '2023-03-11',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '5364.55'},
#  {'data_internacao': '2023-08-08',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '3718.19'},
#  {'data_internacao': '2024-08-19',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '3570.53'},
#  {'data_internacao': '2024-05-23',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '289.96'},
#  {'data_internacao': '2023-12-22',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '8851.79'},
#  {'data_internacao': '2024-02-15',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '5446.16'},
#  {'data_internacao': '2023-06-14',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '4715.37'},
#  {'data_internacao': '2023-02-10',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '402.48'},
#  {'data_internacao': '2023-05-10',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '9395.19'},
#  {'data_internacao': '2024-03-30',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '9528.56'},
#  {'data_internacao': '2023-08-13',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '6600.29'},
#  {'data_internacao': '2024-06-04',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '9711.3'},
#  {'data_internacao': '2023-02-02',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6574.48'},
#  {'data_internacao': '2024-04-03',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '9520.28'},
#  {'data_internacao': '2023-05-01',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '2966.86'},
#  {'data_internacao': '2023-11-23',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '7525.04'},
#  {'data_internacao': '2024-02-15',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '7975.6'},
#  {'data_internacao': '2022-12-18',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '3688.74'},
#  {'data_internacao': '2024-08-08',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '702.89'},
#  {'data_internacao': '2024-01-02',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '6359.33'},
#  {'data_internacao': '2024-03-31',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7079.71'},
#  {'data_internacao': '2023-08-20',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '6372.26'},
#  {'data_internacao': '2023-02-07',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '3754.55'},
#  {'data_internacao': '2024-08-25',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '2403.42'},
#  {'data_internacao': '2022-10-08',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '3143.79'},
#  {'data_internacao': '2023-12-15',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '4019.87'},
#  {'data_internacao': '2023-06-13',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '5026.68'},
#  {'data_internacao': '2023-08-20',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '4332.71'},
#  {'data_internacao': '2024-07-20',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '1522.11'},
#  {'data_internacao': '2022-10-19',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '6481.68'},
#  {'data_internacao': '2023-01-28',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '3495.82'},
#  {'data_internacao': '2023-09-24',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '2421.11'},
#  {'data_internacao': '2023-03-04',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '4357.3'},
#  {'data_internacao': '2023-07-12',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '3750.79'},
#  {'data_internacao': '2024-09-22',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '3021.87'},
#  {'data_internacao': '2023-03-25',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '7086.43'},
#  {'data_internacao': '2022-12-27',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '690.38'},
#  {'data_internacao': '2024-06-13',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '2482.84'},
#  {'data_internacao': '2022-12-04',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '1203.35'},
#  {'data_internacao': '2024-01-30',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '9285.1'},
#  {'data_internacao': '2023-04-14',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '2362.29'},
#  {'data_internacao': '2024-03-06',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '3323.4'},
#  {'data_internacao': '2023-08-27',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '9622.98'},
#  {'data_internacao': '2023-02-03',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '8150.32'},
#  {'data_internacao': '2023-02-18',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '1851.33'},
#  {'data_internacao': '2023-01-23',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3120.37'},
#  {'data_internacao': '2024-04-01',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '4171.83'},
#  {'data_internacao': '2022-12-13',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '4015.76'},
#  {'data_internacao': '2023-03-18',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '4931.58'},
#  {'data_internacao': '2024-01-17',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '9459.13'},
#  {'data_internacao': '2023-08-07',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '3381.56'},
#  {'data_internacao': '2022-12-16',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '9222.3'},
#  {'data_internacao': '2023-10-22',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '3686.15'},
#  {'data_internacao': '2024-07-03',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '2242.57'},
#  {'data_internacao': '2023-07-24',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '5344.28'},
#  {'data_internacao': '2023-04-02',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '2624.09'},
#  {'data_internacao': '2023-01-28',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '5492.37'},
#  {'data_internacao': '2023-09-29',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '4917.07'},
#  {'data_internacao': '2023-03-17',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '7093.13'},
#  {'data_internacao': '2024-01-14',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '1966.66'},
#  {'data_internacao': '2024-04-09',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '473.74'},
#  {'data_internacao': '2024-03-14',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '914.05'},
#  {'data_internacao': '2023-04-09',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '6566.88'},
#  {'data_internacao': '2022-12-30',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '862.22'},
#  {'data_internacao': '2023-10-18',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '2708.72'},
#  {'data_internacao': '2023-12-14',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '1441.39'},
#  {'data_internacao': '2023-01-24',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '9104.0'},
#  {'data_internacao': '2022-11-17',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '8240.37'},
#  {'data_internacao': '2022-10-22',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '3927.59'},
#  {'data_internacao': '2023-09-22',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '3417.12'},
#  {'data_internacao': '2023-09-21',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '1991.07'},
#  {'data_internacao': '2023-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '2836.08'},
#  {'data_internacao': '2023-01-01',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '9604.95'},
#  {'data_internacao': '2023-06-30',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '5012.19'},
#  {'data_internacao': '2023-05-13',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7848.92'},
#  {'data_internacao': '2024-09-30',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '3644.7'},
#  {'data_internacao': '2022-10-25',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '2424.04'},
#  {'data_internacao': '2023-03-28',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6734.87'},
#  {'data_internacao': '2023-12-22',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '951.92'},
#  {'data_internacao': '2024-07-13',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '6983.92'},
#  {'data_internacao': '2024-05-15',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '3706.28'},
#  {'data_internacao': '2024-02-01',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '1923.4'},
#  {'data_internacao': '2023-07-23',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3249.23'},
#  {'data_internacao': '2023-07-19',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7023.33'},
#  {'data_internacao': '2024-02-15',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '5561.99'},
#  {'data_internacao': '2024-02-08',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '9142.85'},
#  {'data_internacao': '2024-06-04',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '8311.59'},
#  {'data_internacao': '2023-04-22',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '8347.95'},
#  {'data_internacao': '2024-03-27',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '1347.45'},
#  {'data_internacao': '2024-05-28',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7258.23'},
#  {'data_internacao': '2024-05-24',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '9303.68'},
#  {'data_internacao': '2024-07-08',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '4966.84'},
#  {'data_internacao': '2023-02-03',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '7402.53'},
#  {'data_internacao': '2023-03-24',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '8102.5'},
#  {'data_internacao': '2023-07-08',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '7605.94'},
#  {'data_internacao': '2022-12-23',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '4117.4'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '5925.2'},
#  {'data_internacao': '2023-04-09',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '9552.77'},
#  {'data_internacao': '2024-06-30',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '2144.8'},
#  {'data_internacao': '2024-06-19',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '9348.41'},
#  {'data_internacao': '2024-02-24',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '7887.33'},
#  {'data_internacao': '2024-01-24',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '8772.07'},
#  {'data_internacao': '2023-10-20',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '5478.03'},
#  {'data_internacao': '2024-07-20',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '3829.26'},
#  {'data_internacao': '2023-07-19',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '8143.96'},
#  {'data_internacao': '2023-04-19',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '5601.75'},
#  {'data_internacao': '2024-03-15',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '9539.6'},
#  {'data_internacao': '2024-03-03',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '7028.52'},
#  {'data_internacao': '2023-07-19',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '1428.37'},
#  {'data_internacao': '2024-04-01',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '9187.58'},
#  {'data_internacao': '2024-01-07',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '8170.23'},
#  {'data_internacao': '2024-02-16',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '7898.52'},
#  {'data_internacao': '2024-04-26',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '1329.67'},
#  {'data_internacao': '2024-09-17',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '4153.21'},
#  {'data_internacao': '2024-04-21',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '9199.94'},
#  {'data_internacao': '2023-08-16',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '5734.05'},
#  {'data_internacao': '2023-12-14',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '9158.74'},
#  {'data_internacao': '2024-09-15',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '1692.78'},
#  {'data_internacao': '2022-10-24',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '9496.59'},
#  {'data_internacao': '2024-09-30',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '7679.46'},
#  {'data_internacao': '2024-09-10',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '9570.25'},
#  {'data_internacao': '2023-09-12',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5967.52'},
#  {'data_internacao': '2024-03-03',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '7041.55'},
#  {'data_internacao': '2023-08-17',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '9879.93'},
#  {'data_internacao': '2023-10-19',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '5796.55'},
#  {'data_internacao': '2023-11-12',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '154.47'},
#  {'data_internacao': '2023-04-26',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '2163.0'},
#  {'data_internacao': '2024-03-30',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3604.7'},
#  {'data_internacao': '2023-06-03',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '2658.61'},
#  {'data_internacao': '2024-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '7658.35'},
#  {'data_internacao': '2023-12-11',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '9917.78'},
#  {'data_internacao': '2024-08-21',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '4001.65'},
#  {'data_internacao': '2022-11-11',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '1405.78'},
#  {'data_internacao': '2023-03-10',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '6287.85'},
#  {'data_internacao': '2023-12-24',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '8305.77'},
#  {'data_internacao': '2023-04-09',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '2208.91'},
#  {'data_internacao': '2023-06-14',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '5918.77'},
#  {'data_internacao': '2023-11-03',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '1205.0'},
#  {'data_internacao': '2022-11-22',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '8558.29'},
#  {'data_internacao': '2024-08-28',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '8271.98'},
#  {'data_internacao': '2023-04-10',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '2803.41'},
#  {'data_internacao': '2024-08-05',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '223.52'},
#  {'data_internacao': '2023-08-24',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '7759.82'},
#  {'data_internacao': '2024-02-11',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '7649.75'},
#  {'data_internacao': '2023-09-26',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '9836.91'},
#  {'data_internacao': '2023-02-09',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '5076.5'},
#  {'data_internacao': '2023-05-26',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '496.13'},
#  {'data_internacao': '2023-05-21',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '5315.59'},
#  {'data_internacao': '2024-07-10',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '1002.1'},
#  {'data_internacao': '2023-03-31',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '4271.7'},
#  {'data_internacao': '2023-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '3255.91'},
#  {'data_internacao': '2023-05-13',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '8020.49'},
#  {'data_internacao': '2023-04-27',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7275.84'},
#  {'data_internacao': '2023-05-14',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '5402.9'},
#  {'data_internacao': '2023-06-17',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '9263.75'},
#  {'data_internacao': '2024-01-13',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '5143.03'},
#  {'data_internacao': '2024-05-04',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '4416.18'},
#  {'data_internacao': '2023-01-30',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '9942.84'},
#  {'data_internacao': '2022-11-12',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '1984.02'},
#  {'data_internacao': '2023-12-08',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '4705.61'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '5598.75'},
#  {'data_internacao': '2024-01-21',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '7829.07'},
#  {'data_internacao': '2024-07-09',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '1800.01'},
#  {'data_internacao': '2024-02-10',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '230.61'},
#  {'data_internacao': '2024-02-15',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '6347.36'},
#  {'data_internacao': '2024-01-07',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '3685.69'},
#  {'data_internacao': '2023-02-17',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '8475.55'},
#  {'data_internacao': '2024-05-06',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '3439.58'},
#  {'data_internacao': '2024-03-02',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '9262.33'},
#  {'data_internacao': '2023-09-09',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '8809.53'},
#  {'data_internacao': '2023-11-18',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '6430.02'},
#  {'data_internacao': '2023-06-15',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '2524.06'},
#  {'data_internacao': '2023-05-29',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '7008.96'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '5309.54'},
#  {'data_internacao': '2024-03-30',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '3837.11'},
#  {'data_internacao': '2024-05-31',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '9414.11'},
#  {'data_internacao': '2024-02-24',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '1476.12'},
#  {'data_internacao': '2024-06-12',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '2329.74'},
#  {'data_internacao': '2023-12-02',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '1719.04'},
#  {'data_internacao': '2023-04-09',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '6310.29'},
#  {'data_internacao': '2023-06-26',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '859.0'},
#  {'data_internacao': '2023-01-10',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '320.32'},
#  {'data_internacao': '2023-05-02',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '5458.28'},
#  {'data_internacao': '2024-05-02',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '7499.22'},
#  {'data_internacao': '2023-05-22',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '6283.4'},
#  {'data_internacao': '2023-07-20',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5544.58'},
#  {'data_internacao': '2024-07-22',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '968.31'},
#  {'data_internacao': '2023-01-02',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '4660.27'},
#  {'data_internacao': '2023-11-06',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '899.53'},
#  {'data_internacao': '2023-05-28',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '6294.87'},
#  {'data_internacao': '2023-02-11',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '9217.0'},
#  {'data_internacao': '2023-09-13',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '4604.67'},
#  {'data_internacao': '2024-03-01',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '795.55'},
#  {'data_internacao': '2023-10-22',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '7626.84'},
#  {'data_internacao': '2022-11-24',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '8062.0'},
#  {'data_internacao': '2023-01-09',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '273.05'},
#  {'data_internacao': '2023-11-26',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '9344.3'},
#  {'data_internacao': '2023-03-28',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '989.26'},
#  {'data_internacao': '2024-04-01',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '2964.19'},
#  {'data_internacao': '2023-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '1156.01'},
#  {'data_internacao': '2024-06-04',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '8802.08'},
#  {'data_internacao': '2023-08-22',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '3754.88'},
#  {'data_internacao': '2024-07-15',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '4842.82'},
#  {'data_internacao': '2023-08-10',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3448.16'},
#  {'data_internacao': '2024-07-07',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '5138.25'},
#  {'data_internacao': '2024-01-24',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '1749.53'},
#  {'data_internacao': '2023-04-16',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6771.43'},
#  {'data_internacao': '2023-11-11',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '183.8'},
#  {'data_internacao': '2022-12-12',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '8409.0'},
#  {'data_internacao': '2024-05-01',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '4285.15'},
#  {'data_internacao': '2024-09-25',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '559.15'},
#  {'data_internacao': '2024-07-03',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '2999.31'},
#  {'data_internacao': '2024-06-18',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '4758.19'},
#  {'data_internacao': '2024-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '264.12'},
#  {'data_internacao': '2023-08-06',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '5587.18'},
#  {'data_internacao': '2024-08-05',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '9694.95'},
#  {'data_internacao': '2024-07-17',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '9405.11'},
#  {'data_internacao': '2022-12-06',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '9473.27'},
#  {'data_internacao': '2023-11-27',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '9100.23'},
#  {'data_internacao': '2023-09-05',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '3664.55'},
#  {'data_internacao': '2023-01-11',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '9723.57'},
#  {'data_internacao': '2024-04-04',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '1213.23'},
#  {'data_internacao': '2024-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '2197.97'},
#  {'data_internacao': '2023-05-22',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '5075.54'},
#  {'data_internacao': '2023-03-16',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '6028.03'},
#  {'data_internacao': '2023-10-16',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '4859.25'},
#  {'data_internacao': '2023-03-16',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '8542.84'},
#  {'data_internacao': '2023-02-02',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '4731.5'},
#  {'data_internacao': '2023-03-11',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '1085.14'},
#  {'data_internacao': '2024-07-16',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '7421.77'},
#  {'data_internacao': '2023-12-24',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '5331.5'},
#  {'data_internacao': '2024-06-27',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '9001.53'},
#  {'data_internacao': '2024-07-09',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '354.47'},
#  {'data_internacao': '2023-11-27',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6202.6'},
#  {'data_internacao': '2024-03-14',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '7854.51'},
#  {'data_internacao': '2023-12-21',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '8165.7'},
#  {'data_internacao': '2023-10-04',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '531.51'},
#  {'data_internacao': '2024-02-17',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '2308.15'},
#  {'data_internacao': '2023-11-18',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '5843.62'},
#  {'data_internacao': '2023-12-05',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '1265.04'},
#  {'data_internacao': '2023-10-12',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '3304.49'},
#  {'data_internacao': '2024-06-23',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '5662.88'},
#  {'data_internacao': '2023-05-10',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '9681.53'},
#  {'data_internacao': '2023-04-20',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '5965.81'},
#  {'data_internacao': '2024-01-13',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '240.58'},
#  {'data_internacao': '2023-08-19',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '1894.99'},
#  {'data_internacao': '2023-12-16',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '1539.96'},
#  {'data_internacao': '2022-12-14',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7591.0'},
#  {'data_internacao': '2022-11-19',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '2826.0'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '2449.34'},
#  {'data_internacao': '2024-08-12',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '6565.96'},
#  {'data_internacao': '2023-06-26',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '2447.75'},
#  {'data_internacao': '2023-04-07',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '7455.15'},
#  {'data_internacao': '2023-05-06',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '8166.33'},
#  {'data_internacao': '2024-07-29',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '466.54'},
#  {'data_internacao': '2024-02-14',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '9373.97'},
#  {'data_internacao': '2022-10-17',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '827.56'},
#  {'data_internacao': '2023-06-11',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '8245.69'},
#  {'data_internacao': '2024-08-27',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '976.61'},
#  {'data_internacao': '2023-08-11',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '3254.98'},
#  {'data_internacao': '2024-08-21',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '3048.77'},
#  {'data_internacao': '2024-01-17',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '8893.02'},
#  {'data_internacao': '2024-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '8395.3'},
#  {'data_internacao': '2024-03-03',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '1077.46'},
#  {'data_internacao': '2024-08-10',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '1765.14'},
#  {'data_internacao': '2024-03-29',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '2554.77'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '4428.05'},
#  {'data_internacao': '2022-10-30',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '4343.69'},
#  {'data_internacao': '2024-04-23',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '3505.19'},
#  {'data_internacao': '2023-06-11',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '9868.92'},
#  {'data_internacao': '2023-04-27',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '2253.58'},
#  {'data_internacao': '2023-08-17',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '3341.02'},
#  {'data_internacao': '2024-01-27',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '302.74'},
#  {'data_internacao': '2023-12-25',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '6571.0'},
#  {'data_internacao': '2023-08-27',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '9987.84'},
#  {'data_internacao': '2024-01-13',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '3009.59'},
#  {'data_internacao': '2024-02-23',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '4008.18'},
#  {'data_internacao': '2024-08-17',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '1835.87'},
#  {'data_internacao': '2023-11-16',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '8231.94'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '7076.92'},
#  {'data_internacao': '2023-07-26',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '2528.12'},
#  {'data_internacao': '2023-04-27',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '8586.34'},
#  {'data_internacao': '2024-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '9506.59'},
#  {'data_internacao': '2023-09-11',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '5032.74'},
#  {'data_internacao': '2023-05-12',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '4338.36'},
#  {'data_internacao': '2023-07-16',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '8585.26'},
#  {'data_internacao': '2024-01-14',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '3135.08'},
#  {'data_internacao': '2024-10-04',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '6628.58'},
#  {'data_internacao': '2024-07-31',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '300.27'},
#  {'data_internacao': '2023-11-05',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '9788.0'},
#  {'data_internacao': '2024-09-17',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '3120.55'},
#  {'data_internacao': '2022-12-19',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '4733.81'},
#  {'data_internacao': '2023-05-01',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '3634.5'},
#  {'data_internacao': '2023-06-05',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '6364.1'},
#  {'data_internacao': '2023-10-06',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '9502.63'},
#  {'data_internacao': '2023-10-01',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '1336.6'},
#  {'data_internacao': '2023-02-23',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '2079.07'},
#  {'data_internacao': '2023-11-28',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '6766.07'},
#  {'data_internacao': '2024-09-14',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '8001.28'},
#  {'data_internacao': '2023-10-14',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '8659.43'},
#  {'data_internacao': '2023-10-30',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '5804.28'},
#  {'data_internacao': '2022-11-28',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '1892.64'},
#  {'data_internacao': '2022-10-22',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '5585.72'},
#  {'data_internacao': '2024-08-14',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '5475.49'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7907.92'},
#  {'data_internacao': '2024-07-18',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '6817.74'},
#  {'data_internacao': '2023-07-30',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5889.42'},
#  {'data_internacao': '2022-11-07',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '6006.4'},
#  {'data_internacao': '2023-11-08',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '5631.13'},
#  {'data_internacao': '2023-11-06',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '5244.6'},
#  {'data_internacao': '2023-09-11',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '9538.94'},
#  {'data_internacao': '2023-06-12',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '8015.33'},
#  {'data_internacao': '2023-01-12',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '9009.19'},
#  {'data_internacao': '2024-04-12',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '4652.44'},
#  {'data_internacao': '2023-01-01',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '5584.35'},
#  {'data_internacao': '2024-01-10',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '2301.58'},
#  {'data_internacao': '2024-04-29',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '5656.88'},
#  {'data_internacao': '2023-06-22',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '4037.97'},
#  {'data_internacao': '2024-07-05',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '4242.09'},
#  {'data_internacao': '2024-02-09',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '5251.92'},
#  {'data_internacao': '2024-05-23',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '8740.81'},
#  {'data_internacao': '2023-01-05',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '633.19'},
#  {'data_internacao': '2023-07-29',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '3658.57'},
#  {'data_internacao': '2023-01-10',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '9288.24'},
#  {'data_internacao': '2023-06-28',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '3557.3'},
#  {'data_internacao': '2023-02-07',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '1953.24'},
#  {'data_internacao': '2024-08-25',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '339.06'},
#  {'data_internacao': '2023-04-15',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '8484.11'},
#  {'data_internacao': '2023-06-22',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '1993.99'},
#  {'data_internacao': '2022-10-23',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '4176.41'},
#  {'data_internacao': '2023-04-05',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '6112.29'},
#  {'data_internacao': '2024-08-06',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '3514.93'},
#  {'data_internacao': '2024-09-08',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '7274.73'},
#  {'data_internacao': '2023-05-07',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '1040.36'},
#  {'data_internacao': '2024-07-12',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '2490.97'},
#  {'data_internacao': '2024-10-03',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '2954.37'},
#  {'data_internacao': '2023-06-09',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '5060.85'},
#  {'data_internacao': '2024-06-06',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '4709.33'},
#  {'data_internacao': '2022-11-16',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '949.0'},
#  {'data_internacao': '2024-08-17',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '2198.26'},
#  {'data_internacao': '2022-12-12',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '8912.29'},
#  {'data_internacao': '2024-05-20',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '9532.77'},
#  {'data_internacao': '2023-01-02',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3414.08'},
#  {'data_internacao': '2023-01-12',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '5672.39'},
#  {'data_internacao': '2024-08-18',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '8638.06'},
#  {'data_internacao': '2023-04-19',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '8002.9'},
#  {'data_internacao': '2024-10-04',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '4151.17'},
#  {'data_internacao': '2023-03-10',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '2750.84'},
#  {'data_internacao': '2023-12-30',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '8684.54'},
#  {'data_internacao': '2023-03-31',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '5094.25'},
#  {'data_internacao': '2023-09-21',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '7164.71'},
#  {'data_internacao': '2022-11-02',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '4149.55'},
#  {'data_internacao': '2023-06-28',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '1379.14'},
#  {'data_internacao': '2024-03-23',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '4481.27'},
#  {'data_internacao': '2024-05-06',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '8649.86'},
#  {'data_internacao': '2023-08-29',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '502.87'},
#  {'data_internacao': '2022-10-11',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '5728.29'},
#  {'data_internacao': '2023-09-04',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '3520.9'},
#  {'data_internacao': '2023-09-29',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '2677.57'},
#  {'data_internacao': '2023-12-19',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '9004.75'},
#  {'data_internacao': '2023-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '3390.01'},
#  {'data_internacao': '2023-01-23',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '2864.52'},
#  {'data_internacao': '2023-06-26',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '7917.93'},
#  {'data_internacao': '2024-08-17',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '8435.42'},
#  {'data_internacao': '2024-06-12',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '951.44'},
#  {'data_internacao': '2023-12-01',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '8374.03'},
#  {'data_internacao': '2024-04-06',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '4693.94'},
#  {'data_internacao': '2023-07-05',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '9243.83'},
#  {'data_internacao': '2023-08-24',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '5302.53'},
#  {'data_internacao': '2023-05-31',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '1319.34'},
#  {'data_internacao': '2023-08-27',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '4056.15'},
#  {'data_internacao': '2023-02-05',
#   'tratamento': 'i',
#   'dias_internacao': '18',
#   'custo_total': '1836.68'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '3388.21'},
#  {'data_internacao': '2024-05-30',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '5803.51'},
#  {'data_internacao': '2023-01-26',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '7479.66'},
#  {'data_internacao': '2023-07-23',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '9192.65'},
#  {'data_internacao': '2024-09-16',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '1700.31'},
#  {'data_internacao': '2024-06-14',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '354.18'},
#  {'data_internacao': '2024-06-23',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '867.46'},
#  {'data_internacao': '2024-04-05',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '8828.27'},
#  {'data_internacao': '2024-08-29',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '8375.08'},
#  {'data_internacao': '2024-04-11',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '313.65'},
#  {'data_internacao': '2024-06-28',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '6594.73'},
#  {'data_internacao': '2023-05-31',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '8752.05'},
#  {'data_internacao': '2024-09-20',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '2327.3'},
#  {'data_internacao': '2023-02-28',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '5133.48'},
#  {'data_internacao': '2022-11-11',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '9123.45'},
#  {'data_internacao': '2022-10-26',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '5240.97'},
#  {'data_internacao': '2023-02-21',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '2029.64'},
#  {'data_internacao': '2023-07-20',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '8910.95'},
#  {'data_internacao': '2022-11-29',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '5491.12'},
#  {'data_internacao': '2022-11-30',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '7931.51'},
#  {'data_internacao': '2024-06-27',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '6284.6'},
#  {'data_internacao': '2023-11-15',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '3633.24'},
#  {'data_internacao': '2024-08-07',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '8644.51'},
#  {'data_internacao': '2023-01-30',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '1617.08'},
#  {'data_internacao': '2024-07-16',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '8654.03'},
#  {'data_internacao': '2022-10-09',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '3155.39'},
#  {'data_internacao': '2023-06-21',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '1815.44'},
#  {'data_internacao': '2024-05-20',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '4476.47'},
#  {'data_internacao': '2023-10-20',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '8244.21'},
#  {'data_internacao': '2023-08-11',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '9166.92'},
#  {'data_internacao': '2024-01-09',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '2047.86'},
#  {'data_internacao': '2024-01-16',
# ...
#   'custo_total': '8512.8'},
#  {'data_internacao': '2024-01-05',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '9343.42'},
#  {'data_internacao': '2023-01-07',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '8222.23'},
#  {'data_internacao': '2023-04-11',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '6674.88'},
#  {'data_internacao': '2022-12-29',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '3273.23'},
#  {'data_internacao': '2023-03-07',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '6169.4'},
#  {'data_internacao': '2023-03-24',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7099.57'},
#  {'data_internacao': '2023-07-10',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '5712.09'},
#  {'data_internacao': '2024-07-20',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '9410.94'},
#  {'data_internacao': '2024-04-15',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '3785.07'},
#  {'data_internacao': '2024-08-11',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '6162.31'},
#  {'data_internacao': '2023-03-25',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '523.8'},
#  {'data_internacao': '2024-05-07',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '6565.79'},
#  {'data_internacao': '2024-08-26',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '9756.52'},
#  {'data_internacao': '2024-06-29',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '7152.26'},
#  {'data_internacao': '2024-04-30',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '2100.15'},
#  {'data_internacao': '2024-03-18',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '3979.38'},
#  {'data_internacao': '2023-07-09',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '5094.89'},
#  {'data_internacao': '2024-01-23',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '7407.15'},
#  {'data_internacao': '2023-03-26',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '9824.23'},
#  {'data_internacao': '2024-01-12',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '2087.92'},
#  {'data_internacao': '2024-05-03',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '3881.04'},
#  {'data_internacao': '2024-07-16',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '7567.94'},
#  {'data_internacao': '2023-09-06',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '5154.32'},
#  {'data_internacao': '2023-06-03',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '7670.88'},
#  {'data_internacao': '2023-03-12',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '3771.87'},
#  {'data_internacao': '2023-03-05',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '925.91'},
#  {'data_internacao': '2024-03-05',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '8528.98'},
#  {'data_internacao': '2023-07-24',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '8010.58'},
#  {'data_internacao': '2024-06-14',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '9247.11'},
#  {'data_internacao': '2022-12-08',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '4552.17'},
#  {'data_internacao': '2024-05-16',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '2385.87'},
#  {'data_internacao': '2023-03-20',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '498.19'},
#  {'data_internacao': '2024-05-21',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '501.92'},
#  {'data_internacao': '2024-02-19',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '852.34'},
#  {'data_internacao': '2023-12-02',
#   'tratamento': 'i',
#   'dias_internacao': '27',
#   'custo_total': '5002.62'},
#  {'data_internacao': '2023-05-06',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '9261.12'},
#  {'data_internacao': '2024-06-25',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '9075.18'},
#  {'data_internacao': '2024-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7700.73'},
#  {'data_internacao': '2024-08-29',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6712.82'},
#  {'data_internacao': '2023-08-27',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '7754.0'},
#  {'data_internacao': '2024-07-26',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '5598.44'},
#  {'data_internacao': '2023-11-20',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '2377.84'},
#  {'data_internacao': '2023-02-25',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '7933.95'},
#  {'data_internacao': '2022-11-24',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '1619.0'},
#  {'data_internacao': '2024-01-28',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '9398.67'},
#  {'data_internacao': '2023-03-22',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '4283.33'},
#  {'data_internacao': '2022-11-10',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '8107.06'},
#  {'data_internacao': '2022-12-22',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '5960.94'},
#  {'data_internacao': '2023-08-16',
#   'tratamento': 'i',
#   'dias_internacao': '5',
#   'custo_total': '6755.08'},
#  {'data_internacao': '2024-07-09',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '1180.51'},
#  {'data_internacao': '2024-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '5397.65'},
#  {'data_internacao': '2023-03-28',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '5580.09'},
#  {'data_internacao': '2023-06-30',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '9980.43'},
#  {'data_internacao': '2022-10-29',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '6130.38'},
#  {'data_internacao': '2024-08-24',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '6350.03'},
#  {'data_internacao': '2022-10-29',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '5028.88'},
#  {'data_internacao': '2023-11-18',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '3886.16'},
#  {'data_internacao': '2023-07-30',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '4683.39'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '9317.24'},
#  {'data_internacao': '2023-12-04',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '3399.66'},
#  {'data_internacao': '2023-07-01',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '3767.81'},
#  {'data_internacao': '2023-01-05',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '550.87'},
#  {'data_internacao': '2023-02-13',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7111.86'},
#  {'data_internacao': '2022-11-01',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '7726.42'},
#  {'data_internacao': '2023-07-07',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '967.4'},
#  {'data_internacao': '2023-06-15',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '9292.39'},
#  {'data_internacao': '2023-03-23',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '1225.5'},
#  {'data_internacao': '2023-05-23',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '3819.36'},
#  {'data_internacao': '2023-08-03',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '4782.48'},
#  {'data_internacao': '2023-12-10',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '8270.23'},
#  {'data_internacao': '2023-09-19',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '6922.12'},
#  {'data_internacao': '2023-05-20',
#   'tratamento': 'i',
#   'dias_internacao': '29',
#   'custo_total': '4736.75'},
#  {'data_internacao': '2023-10-14',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '6382.4'},
#  {'data_internacao': '2023-11-16',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '9165.29'},
#  {'data_internacao': '2023-04-24',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '5105.43'},
#  {'data_internacao': '2024-03-22',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '4781.05'},
#  {'data_internacao': '2023-07-26',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '4434.23'},
#  {'data_internacao': '2024-03-04',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '3860.87'},
#  {'data_internacao': '2024-09-12',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '5865.43'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '2623.16'},
#  {'data_internacao': '2022-12-07',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '7514.21'},
#  {'data_internacao': '2023-06-10',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '9389.34'},
#  {'data_internacao': '2024-02-29',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '8033.84'},
#  {'data_internacao': '2024-02-03',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '5133.82'},
#  {'data_internacao': '2023-10-25',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '9451.87'},
#  {'data_internacao': '2023-04-23',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '7090.45'},
#  {'data_internacao': '2023-01-11',
#   'tratamento': 'i',
#   'dias_internacao': '1',
#   'custo_total': '942.14'},
#  {'data_internacao': '2022-12-08',
#   'tratamento': 'i',
#   'dias_internacao': '4',
#   'custo_total': '2826.5'},
#  {'data_internacao': '2023-01-04',
#   'tratamento': 'i',
#   'dias_internacao': '2',
#   'custo_total': '2409.26'},
#  {'data_internacao': '2024-06-22',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '6238.32'},
#  {'data_internacao': '2024-03-12',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7950.84'},
#  {'data_internacao': '2023-10-13',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '3361.2'},
#  {'data_internacao': '2023-12-02',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '5743.73'},
#  {'data_internacao': '2024-06-19',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '1717.2'},
#  {'data_internacao': '2023-07-22',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '6009.46'},
#  {'data_internacao': '2023-07-05',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '9185.16'},
#  {'data_internacao': '2024-02-23',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '9785.26'},
#  {'data_internacao': '2023-08-28',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '7594.06'},
#  {'data_internacao': '2023-03-25',
#   'tratamento': 'i',
#   'dias_internacao': '23',
#   'custo_total': '4829.99'},
#  {'data_internacao': '2023-12-23',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '129.24'},
#  {'data_internacao': '2024-01-10',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '1520.79'},
#  {'data_internacao': '2022-10-13',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '7548.14'},
#  {'data_internacao': '2024-03-04',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '2574.03'},
#  {'data_internacao': '2024-08-20',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '8970.22'},
#  {'data_internacao': '2023-02-16',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '4384.54'},
#  {'data_internacao': '2023-10-18',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '1210.62'},
#  {'data_internacao': '2023-02-13',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '1025.9'},
#  {'data_internacao': '2024-05-08',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '970.87'},
#  {'data_internacao': '2024-06-17',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '9996.22'},
#  {'data_internacao': '2023-01-05',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '1900.12'},
#  {'data_internacao': '2023-04-11',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '2447.6'},
#  {'data_internacao': '2023-06-16',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '6319.21'},
#  {'data_internacao': '2023-12-21',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '4224.04'},
#  {'data_internacao': '2023-02-23',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '3166.56'},
#  {'data_internacao': '2023-08-08',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '8709.72'},
#  {'data_internacao': '2023-08-16',
#   'tratamento': 'i',
#   'dias_internacao': '17',
#   'custo_total': '7825.68'},
#  {'data_internacao': '2023-01-11',
#   'tratamento': 'i',
#   'dias_internacao': '16',
#   'custo_total': '821.62'},
#  {'data_internacao': '2024-05-31',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '7675.56'},
#  {'data_internacao': '2023-04-01',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '753.1'},
#  {'data_internacao': '2023-02-05',
#   'tratamento': 'i',
#   'dias_internacao': '13',
#   'custo_total': '4500.67'},
#  {'data_internacao': '2024-06-07',
#   'tratamento': 'i',
#   'dias_internacao': '7',
#   'custo_total': '6625.33'},
#  {'data_internacao': '2023-06-23',
#   'tratamento': 'i',
#   'dias_internacao': '26',
#   'custo_total': '7487.74'},
#  {'data_internacao': '2023-09-05',
#   'tratamento': 'i',
#   'dias_internacao': '21',
#   'custo_total': '8291.19'},
#  {'data_internacao': '2023-12-29',
#   'tratamento': 'i',
#   'dias_internacao': '10',
#   'custo_total': '8222.75'},
#  {'data_internacao': '2023-11-27',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '3051.4'},
#  {'data_internacao': '2024-04-13',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '9737.85'},
#  {'data_internacao': '2023-11-16',
#   'tratamento': 'i',
#   'dias_internacao': '30',
#   'custo_total': '8485.51'},
#  {'data_internacao': '2024-05-11',
#   'tratamento': 'i',
#   'dias_internacao': '8',
#   'custo_total': '3491.92'},
#  {'data_internacao': '2023-10-08',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '3892.54'},
#  {'data_internacao': '2024-09-12',
#   'tratamento': 'i',
#   'dias_internacao': '9',
#   'custo_total': '5797.68'},
#  {'data_internacao': '2024-07-08',
#   'tratamento': 'i',
#   'dias_internacao': '28',
#   'custo_total': '4807.95'},
#  {'data_internacao': '2023-11-22',
#   'tratamento': 'i',
#   'dias_internacao': '11',
#   'custo_total': '4626.33'},
#  {'data_internacao': '2024-04-22',
#   'tratamento': 'i',
#   'dias_internacao': '20',
#   'custo_total': '8299.54'},
#  {'data_internacao': '2024-06-26',
#   'tratamento': 'i',
#   'dias_internacao': '22',
#   'custo_total': '5000.8'},
#  {'data_internacao': '2023-10-20',
#   'tratamento': 'i',
#   'dias_internacao': '19',
#   'custo_total': '5260.06'},
#  {'data_internacao': '2023-02-02',
#   'tratamento': 'i',
#   'dias_internacao': '15',
#   'custo_total': '921.19'},
#  {'data_internacao': '2024-02-07',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '2544.3'},
#  {'data_internacao': '2024-06-11',
#   'tratamento': 'i',
#   'dias_internacao': '12',
#   'custo_total': '2307.7'},
#  {'data_internacao': '2023-10-26',
#   'tratamento': 'i',
#   'dias_internacao': '25',
#   'custo_total': '8418.79'},
#  {'data_internacao': '2023-02-02',
#   'tratamento': 'i',
#   'dias_internacao': '6',
#   'custo_total': '6240.67'},
#  {'data_internacao': '2024-04-06',
#   'tratamento': 'i',
#   'dias_internacao': '3',
#   'custo_total': '7190.47'},
#  {'data_internacao': '2024-04-14',
#   'tratamento': 'i',
#   'dias_internacao': '24',
#   'custo_total': '8952.33'},
#  {'data_internacao': '2023-11-18',
#   'tratamento': 'i',
#   'dias_internacao': '14',
#   'custo_total': '482.93'},
#  ...]

# %% [markdown]
# ### DESAFIO
#
# Termine de construir o módulo de análise

# %% [markdown]
# 1. Crie uma função que calcule o custo médio por internação
# 2. Crie uma função que calcule o volume de internações por tipo de tratamento
#
# 3. Crie uma função que calcule o volume de internações ao longo do tempo, uma visão mensal.

# %%
#Construindo o modulo
analisar_arquivo = '''
import csv
import math
from datetime import datetime

# Funcao para carregar arquivos csv
def carregar_dados(nome_arquivo):
  dados = []
  with open(nome_arquivo, 'r') as arquivo:
    leitor = csv.DictReader(arquivo)
    for linha in leitor:
      dados.append(linha)
  return dados

# Função que calcule o custo médio por internação
def custo_medio(dados):
  custo_total = 0
  for linha in dados:
    custo_total += float(linha['custo_total'])
  custo_medio = custo_total / len(dados)
  return custo_medio

# Função que calcule o volume de internações por tipo de tratamento
def volume_internacao_tratamento(dados):
    volume_por_tratamento = {}
    for linha in dados:
        tratamento = linha['tratamento']
        if tratamento in volume_por_tratamento:
            volume_por_tratamento[tratamento] += 1
        else:
            volume_por_tratamento[tratamento] = 1
    return volume_por_tratamento

# Função que calcule o volume de internações ao longo do tempo, uma visão mensal.
def volume_internacao_mensal(dados):
    volume_por_mes = {}
    for linha in dados:
        data_internacao = datetime.strptime(linha['data_internacao'], '%Y-%m-%d')
        mes_ano = data_internacao.strftime('%Y-%m')
        if mes_ano in volume_por_mes:
            volume_por_mes[mes_ano] += 1
        else:
            volume_por_mes[mes_ano] = 1
    return volume_por_mes
'''

# Construindo o arquivo do módulo
with open('modulo_analise_desafio.py', 'w') as modulo:
    modulo.write(conteudo)

# %%
# importando o módulo e definindo como 'mad'
import modulo_analise_desafio as mad

# %%
#criando o arquivo
mi.meu_arquivo('internacao_desafio.csv', 50000)

# %%
# lendo o arquivo
desafio = mad.carregar_dados('internacao_desafio.csv')

# %%
desafio
# Out:
# [{'data_internacao': '2023-05-28',
#   'tratamento': 'tratamento_intensivo',
#   'dias_internacao': '9',
#   'custo_total': '8936.06'},
#  {'data_internacao': '2023-04-01',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '9479.52'},
#  {'data_internacao': '2024-01-27',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '874.42'},
#  {'data_internacao': '2023-08-04',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '7164.7'},
#  {'data_internacao': '2024-01-22',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '9616.91'},
#  {'data_internacao': '2024-09-10',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '5021.86'},
#  {'data_internacao': '2024-05-01',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '8847.83'},
#  {'data_internacao': '2022-11-30',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '4684.23'},
#  {'data_internacao': '2023-09-11',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '5026.27'},
#  {'data_internacao': '2023-05-27',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '118.08'},
#  {'data_internacao': '2022-11-29',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '4410.67'},
#  {'data_internacao': '2024-04-18',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '3578.47'},
#  {'data_internacao': '2022-11-12',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '3581.29'},
#  {'data_internacao': '2024-01-14',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '4204.79'},
#  {'data_internacao': '2023-10-16',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '2966.94'},
#  {'data_internacao': '2024-05-22',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '215.11'},
#  {'data_internacao': '2023-12-31',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '1421.1'},
#  {'data_internacao': '2024-07-19',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '4260.38'},
#  {'data_internacao': '2023-03-08',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '8154.47'},
#  {'data_internacao': '2022-11-08',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '2279.92'},
#  {'data_internacao': '2023-09-26',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '3103.02'},
#  {'data_internacao': '2022-11-20',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '5916.61'},
#  {'data_internacao': '2024-07-24',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '9532.61'},
#  {'data_internacao': '2024-06-06',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '6022.39'},
#  {'data_internacao': '2023-11-04',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '3339.68'},
#  {'data_internacao': '2023-10-17',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '3916.93'},
#  {'data_internacao': '2023-10-08',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '8311.26'},
#  {'data_internacao': '2023-03-29',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '3402.21'},
#  {'data_internacao': '2024-04-28',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '4924.49'},
#  {'data_internacao': '2023-09-08',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '2727.03'},
#  {'data_internacao': '2024-09-14',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '7134.92'},
#  {'data_internacao': '2023-09-04',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '7203.32'},
#  {'data_internacao': '2024-07-18',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '3950.23'},
#  {'data_internacao': '2024-09-07',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '5310.53'},
#  {'data_internacao': '2024-05-29',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '9387.72'},
#  {'data_internacao': '2024-01-19',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '5261.66'},
#  {'data_internacao': '2024-09-03',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '9771.95'},
#  {'data_internacao': '2024-06-13',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '6871.0'},
#  {'data_internacao': '2023-09-02',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '2937.93'},
#  {'data_internacao': '2024-02-03',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '8856.27'},
#  {'data_internacao': '2023-06-25',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '4333.52'},
#  {'data_internacao': '2023-04-12',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '5308.23'},
#  {'data_internacao': '2023-04-08',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '1429.56'},
#  {'data_internacao': '2023-04-22',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '3124.08'},
#  {'data_internacao': '2022-12-20',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '5905.41'},
#  {'data_internacao': '2023-10-04',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '1925.51'},
#  {'data_internacao': '2024-07-08',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '3424.52'},
#  {'data_internacao': '2023-05-28',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '6882.0'},
#  {'data_internacao': '2023-03-17',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '6926.7'},
#  {'data_internacao': '2024-04-22',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '9012.95'},
#  {'data_internacao': '2024-05-05',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '1384.89'},
#  {'data_internacao': '2024-04-24',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '8439.82'},
#  {'data_internacao': '2023-12-03',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '2985.64'},
#  {'data_internacao': '2024-08-15',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '540.79'},
#  {'data_internacao': '2024-01-01',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '8974.47'},
#  {'data_internacao': '2023-03-15',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '432.67'},
#  {'data_internacao': '2023-03-26',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '7949.4'},
#  {'data_internacao': '2023-05-04',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '8300.06'},
#  {'data_internacao': '2024-07-03',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '3677.55'},
#  {'data_internacao': '2024-05-10',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '9385.22'},
#  {'data_internacao': '2022-10-21',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '4193.24'},
#  {'data_internacao': '2023-09-25',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '391.99'},
#  {'data_internacao': '2023-06-04',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '667.4'},
#  {'data_internacao': '2024-02-13',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '1505.2'},
#  {'data_internacao': '2023-07-17',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '3004.84'},
#  {'data_internacao': '2022-11-23',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '9822.39'},
#  {'data_internacao': '2023-12-06',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '2431.07'},
#  {'data_internacao': '2022-12-07',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '3921.45'},
#  {'data_internacao': '2023-07-12',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '7672.68'},
#  {'data_internacao': '2024-01-01',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '6963.73'},
#  {'data_internacao': '2024-04-19',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '3874.74'},
#  {'data_internacao': '2022-12-11',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '7004.51'},
#  {'data_internacao': '2022-12-12',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '3097.19'},
#  {'data_internacao': '2022-12-03',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '9030.37'},
#  {'data_internacao': '2024-02-20',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '6403.27'},
#  {'data_internacao': '2022-12-15',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '2321.55'},
#  {'data_internacao': '2022-11-14',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '2519.55'},
#  {'data_internacao': '2024-02-29',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '5396.56'},
#  {'data_internacao': '2022-11-24',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '3872.03'},
#  {'data_internacao': '2022-11-16',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '4530.5'},
#  {'data_internacao': '2023-10-11',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '2341.75'},
#  {'data_internacao': '2023-11-18',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '3118.14'},
#  {'data_internacao': '2023-08-25',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '8591.29'},
#  {'data_internacao': '2024-01-29',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '3003.03'},
#  {'data_internacao': '2024-01-05',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '7998.11'},
#  {'data_internacao': '2024-08-28',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '2413.49'},
#  {'data_internacao': '2023-03-13',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '8334.36'},
#  {'data_internacao': '2023-02-09',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '1663.76'},
#  {'data_internacao': '2024-07-30',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5927.75'},
#  {'data_internacao': '2023-04-30',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '1680.03'},
#  {'data_internacao': '2022-11-09',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '4183.61'},
#  {'data_internacao': '2024-01-09',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '1735.46'},
#  {'data_internacao': '2024-07-01',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '9013.75'},
#  {'data_internacao': '2023-05-13',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '5883.8'},
#  {'data_internacao': '2023-03-11',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '6302.13'},
#  {'data_internacao': '2023-05-19',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '2797.37'},
#  {'data_internacao': '2024-01-03',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '8044.76'},
#  {'data_internacao': '2024-06-25',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '1699.0'},
#  {'data_internacao': '2024-08-23',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '1083.83'},
#  {'data_internacao': '2022-12-24',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '4721.95'},
#  {'data_internacao': '2024-01-04',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '2727.19'},
#  {'data_internacao': '2024-06-04',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '879.21'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '4971.27'},
#  {'data_internacao': '2024-05-19',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '8347.24'},
#  {'data_internacao': '2023-11-29',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '8845.96'},
#  {'data_internacao': '2024-09-06',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '3910.09'},
#  {'data_internacao': '2023-06-30',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '1899.99'},
#  {'data_internacao': '2024-05-02',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '8479.06'},
#  {'data_internacao': '2023-06-08',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '610.98'},
#  {'data_internacao': '2024-07-14',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '5022.7'},
#  {'data_internacao': '2022-12-23',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '2711.19'},
#  {'data_internacao': '2024-01-24',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '9750.87'},
#  {'data_internacao': '2024-03-18',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '6176.32'},
#  {'data_internacao': '2023-08-07',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '678.2'},
#  {'data_internacao': '2023-08-03',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '564.94'},
#  {'data_internacao': '2023-03-17',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '2819.75'},
#  {'data_internacao': '2022-12-31',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '2585.28'},
#  {'data_internacao': '2024-07-24',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '8025.63'},
#  {'data_internacao': '2023-12-06',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '4610.62'},
#  {'data_internacao': '2023-10-07',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '6595.09'},
#  {'data_internacao': '2023-11-14',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '990.03'},
#  {'data_internacao': '2024-09-16',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '6717.37'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '2003.39'},
#  {'data_internacao': '2023-04-06',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '7851.9'},
#  {'data_internacao': '2024-02-16',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '7433.14'},
#  {'data_internacao': '2023-04-02',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '4020.87'},
#  {'data_internacao': '2023-03-23',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '2394.23'},
#  {'data_internacao': '2024-01-11',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '8803.82'},
#  {'data_internacao': '2023-04-06',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '1610.67'},
#  {'data_internacao': '2023-10-27',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '6653.46'},
#  {'data_internacao': '2024-08-02',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '2052.15'},
#  {'data_internacao': '2023-10-30',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '5585.92'},
#  {'data_internacao': '2024-06-15',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '3331.39'},
#  {'data_internacao': '2022-11-14',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '2260.56'},
#  {'data_internacao': '2024-01-20',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '9715.13'},
#  {'data_internacao': '2022-10-30',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '267.87'},
#  {'data_internacao': '2023-11-27',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '5368.0'},
#  {'data_internacao': '2023-12-06',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '2222.12'},
#  {'data_internacao': '2023-03-27',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '2049.5'},
#  {'data_internacao': '2023-04-08',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '4620.07'},
#  {'data_internacao': '2024-05-19',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '8670.19'},
#  {'data_internacao': '2023-08-18',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '4334.33'},
#  {'data_internacao': '2024-09-11',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '3317.89'},
#  {'data_internacao': '2024-06-07',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '1518.52'},
#  {'data_internacao': '2023-05-21',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '7140.79'},
#  {'data_internacao': '2024-02-19',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '355.17'},
#  {'data_internacao': '2024-08-01',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '6951.37'},
#  {'data_internacao': '2022-12-14',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '2096.7'},
#  {'data_internacao': '2024-05-20',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '3175.52'},
#  {'data_internacao': '2023-09-05',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '3550.86'},
#  {'data_internacao': '2023-07-01',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '6590.1'},
#  {'data_internacao': '2023-03-01',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '425.77'},
#  {'data_internacao': '2022-12-14',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '5834.38'},
#  {'data_internacao': '2023-07-26',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '1543.21'},
#  {'data_internacao': '2023-08-01',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '949.42'},
#  {'data_internacao': '2024-09-24',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '1731.96'},
#  {'data_internacao': '2024-05-10',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '9653.36'},
#  {'data_internacao': '2023-07-25',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '1256.74'},
#  {'data_internacao': '2023-06-07',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '3947.78'},
#  {'data_internacao': '2024-04-07',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '4882.31'},
#  {'data_internacao': '2023-06-27',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '3328.12'},
#  {'data_internacao': '2023-10-22',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '7129.07'},
#  {'data_internacao': '2024-03-26',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '4377.96'},
#  {'data_internacao': '2023-06-27',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4047.64'},
#  {'data_internacao': '2023-04-07',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '9948.84'},
#  {'data_internacao': '2023-02-27',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '8839.81'},
#  {'data_internacao': '2024-02-19',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '670.62'},
#  {'data_internacao': '2023-08-26',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '4589.77'},
#  {'data_internacao': '2024-06-01',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '7794.9'},
#  {'data_internacao': '2023-09-06',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '9589.13'},
#  {'data_internacao': '2024-05-07',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '9434.37'},
#  {'data_internacao': '2024-07-21',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '8526.86'},
#  {'data_internacao': '2024-10-03',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '5956.95'},
#  {'data_internacao': '2023-07-02',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '2501.97'},
#  {'data_internacao': '2023-06-30',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '215.77'},
#  {'data_internacao': '2024-05-14',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '6032.11'},
#  {'data_internacao': '2023-01-19',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '3251.78'},
#  {'data_internacao': '2023-05-15',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '1784.98'},
#  {'data_internacao': '2023-03-18',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '9150.12'},
#  {'data_internacao': '2023-11-19',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '920.96'},
#  {'data_internacao': '2023-12-10',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '4888.93'},
#  {'data_internacao': '2023-07-29',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '2969.86'},
#  {'data_internacao': '2024-02-02',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '1190.43'},
#  {'data_internacao': '2023-07-13',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '9983.21'},
#  {'data_internacao': '2024-08-08',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '5888.42'},
#  {'data_internacao': '2022-12-14',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '2179.79'},
#  {'data_internacao': '2024-08-24',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '7458.55'},
#  {'data_internacao': '2023-05-14',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '8700.86'},
#  {'data_internacao': '2024-06-29',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '7184.41'},
#  {'data_internacao': '2023-06-23',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '9191.63'},
#  {'data_internacao': '2023-12-11',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '3022.69'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '1349.51'},
#  {'data_internacao': '2023-09-20',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4764.54'},
#  {'data_internacao': '2024-02-16',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '8835.41'},
#  {'data_internacao': '2023-03-28',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '6776.09'},
#  {'data_internacao': '2023-08-25',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '605.5'},
#  {'data_internacao': '2024-04-30',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '5816.77'},
#  {'data_internacao': '2023-10-19',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '7629.49'},
#  {'data_internacao': '2023-03-22',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '7831.25'},
#  {'data_internacao': '2024-09-29',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '8390.37'},
#  {'data_internacao': '2024-09-25',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '1339.0'},
#  {'data_internacao': '2024-03-18',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '709.58'},
#  {'data_internacao': '2024-01-02',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '6368.04'},
#  {'data_internacao': '2023-10-25',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '208.09'},
#  {'data_internacao': '2022-10-30',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '6376.57'},
#  {'data_internacao': '2023-06-01',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '3224.4'},
#  {'data_internacao': '2023-02-11',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '168.76'},
#  {'data_internacao': '2024-04-06',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '6083.59'},
#  {'data_internacao': '2023-10-11',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '1706.84'},
#  {'data_internacao': '2023-06-20',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '7463.12'},
#  {'data_internacao': '2022-12-21',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '8156.12'},
#  {'data_internacao': '2023-07-08',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '9356.31'},
#  {'data_internacao': '2022-10-28',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '4389.62'},
#  {'data_internacao': '2024-03-27',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '6867.29'},
#  {'data_internacao': '2022-10-15',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '9035.67'},
#  {'data_internacao': '2023-01-13',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '587.22'},
#  {'data_internacao': '2023-03-12',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '5762.03'},
#  {'data_internacao': '2024-07-12',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '9088.45'},
#  {'data_internacao': '2024-08-04',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '4446.35'},
#  {'data_internacao': '2023-11-30',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '7548.82'},
#  {'data_internacao': '2023-05-19',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '8966.08'},
#  {'data_internacao': '2024-08-13',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '2759.56'},
#  {'data_internacao': '2024-01-29',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '1667.11'},
#  {'data_internacao': '2023-08-15',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '2086.66'},
#  {'data_internacao': '2023-02-04',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '6608.29'},
#  {'data_internacao': '2023-12-31',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '9374.36'},
#  {'data_internacao': '2024-01-18',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '9594.53'},
#  {'data_internacao': '2023-12-20',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '1937.93'},
#  {'data_internacao': '2023-10-24',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '3120.75'},
#  {'data_internacao': '2023-07-16',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '7531.73'},
#  {'data_internacao': '2023-01-26',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '821.97'},
#  {'data_internacao': '2024-07-06',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '4685.62'},
#  {'data_internacao': '2022-12-16',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '2271.68'},
#  {'data_internacao': '2022-10-25',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '6302.92'},
#  {'data_internacao': '2024-04-27',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '139.36'},
#  {'data_internacao': '2023-06-07',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '2803.45'},
#  {'data_internacao': '2023-05-16',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '7085.13'},
#  {'data_internacao': '2023-02-22',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '9806.35'},
#  {'data_internacao': '2023-08-24',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '8461.36'},
#  {'data_internacao': '2023-03-04',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '7168.95'},
#  {'data_internacao': '2024-05-23',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '7338.02'},
#  {'data_internacao': '2023-12-11',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '7172.95'},
#  {'data_internacao': '2023-03-10',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4962.79'},
#  {'data_internacao': '2022-10-12',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '7629.77'},
#  {'data_internacao': '2023-09-07',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1052.11'},
#  {'data_internacao': '2024-04-08',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '4140.87'},
#  {'data_internacao': '2024-03-13',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '2300.48'},
#  {'data_internacao': '2022-10-17',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '8415.03'},
#  {'data_internacao': '2023-02-22',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '3975.08'},
#  {'data_internacao': '2024-09-22',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '6551.08'},
#  {'data_internacao': '2023-09-01',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '5867.2'},
#  {'data_internacao': '2023-02-05',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '8294.98'},
#  {'data_internacao': '2023-07-13',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '8845.32'},
#  {'data_internacao': '2023-01-29',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '5625.8'},
#  {'data_internacao': '2023-11-23',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '7926.02'},
#  {'data_internacao': '2024-03-19',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '2854.46'},
#  {'data_internacao': '2024-05-17',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1012.62'},
#  {'data_internacao': '2024-05-26',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '3831.66'},
#  {'data_internacao': '2022-10-13',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '5131.36'},
#  {'data_internacao': '2023-08-16',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '9164.98'},
#  {'data_internacao': '2023-08-29',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '7589.79'},
#  {'data_internacao': '2023-04-11',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '3059.15'},
#  {'data_internacao': '2024-07-21',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '1106.05'},
#  {'data_internacao': '2024-04-14',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '6487.57'},
#  {'data_internacao': '2024-04-03',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1563.06'},
#  {'data_internacao': '2023-04-03',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '6101.19'},
#  {'data_internacao': '2024-07-25',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '114.43'},
#  {'data_internacao': '2024-07-06',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '9520.64'},
#  {'data_internacao': '2022-10-30',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '3002.26'},
#  {'data_internacao': '2023-04-07',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '1524.21'},
#  {'data_internacao': '2022-11-24',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '7786.24'},
#  {'data_internacao': '2023-08-24',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '7373.79'},
#  {'data_internacao': '2022-10-18',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '4435.86'},
#  {'data_internacao': '2023-03-22',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '8635.01'},
#  {'data_internacao': '2023-04-22',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '5605.47'},
#  {'data_internacao': '2023-09-19',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '9205.13'},
#  {'data_internacao': '2023-12-02',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '8920.99'},
#  {'data_internacao': '2023-03-08',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '8994.41'},
#  {'data_internacao': '2023-10-02',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '444.86'},
#  {'data_internacao': '2022-10-09',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '1239.57'},
#  {'data_internacao': '2023-10-27',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '5362.66'},
#  {'data_internacao': '2023-11-20',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '8964.8'},
#  {'data_internacao': '2022-11-03',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '1340.07'},
#  {'data_internacao': '2023-01-13',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '9624.77'},
#  {'data_internacao': '2023-05-19',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '7413.02'},
#  {'data_internacao': '2022-11-08',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '7693.88'},
#  {'data_internacao': '2023-11-12',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '9351.25'},
#  {'data_internacao': '2023-02-19',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '1765.06'},
#  {'data_internacao': '2024-05-13',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '7578.64'},
#  {'data_internacao': '2022-12-12',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5117.0'},
#  {'data_internacao': '2022-11-13',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '6309.54'},
#  {'data_internacao': '2022-10-10',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '2428.56'},
#  {'data_internacao': '2023-05-22',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '5626.66'},
#  {'data_internacao': '2024-02-18',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '6437.25'},
#  {'data_internacao': '2024-02-24',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '4631.59'},
#  {'data_internacao': '2024-06-19',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '4022.39'},
#  {'data_internacao': '2023-01-11',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '9796.25'},
#  {'data_internacao': '2023-03-18',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '996.9'},
#  {'data_internacao': '2023-03-13',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '7826.24'},
#  {'data_internacao': '2023-01-05',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '2650.47'},
#  {'data_internacao': '2023-08-02',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '9193.48'},
#  {'data_internacao': '2024-06-28',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '4238.81'},
#  {'data_internacao': '2023-07-09',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '3766.51'},
#  {'data_internacao': '2024-09-07',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '1205.13'},
#  {'data_internacao': '2023-08-14',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4183.65'},
#  {'data_internacao': '2023-08-25',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '5492.99'},
#  {'data_internacao': '2024-04-12',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '9589.42'},
#  {'data_internacao': '2023-04-22',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '3247.11'},
#  {'data_internacao': '2022-10-07',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '3723.81'},
#  {'data_internacao': '2024-06-09',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '8213.99'},
#  {'data_internacao': '2023-05-08',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '3585.48'},
#  {'data_internacao': '2024-09-12',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '9285.53'},
#  {'data_internacao': '2023-04-18',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '8756.42'},
#  {'data_internacao': '2024-06-16',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '9723.94'},
#  {'data_internacao': '2023-02-17',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '4618.92'},
#  {'data_internacao': '2023-03-27',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '3502.28'},
#  {'data_internacao': '2023-05-06',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '7329.57'},
#  {'data_internacao': '2023-03-24',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '1817.93'},
#  {'data_internacao': '2024-10-03',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '1635.29'},
#  {'data_internacao': '2023-11-27',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5810.99'},
#  {'data_internacao': '2023-04-28',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '5805.97'},
#  {'data_internacao': '2023-08-05',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '7010.64'},
#  {'data_internacao': '2023-03-15',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '7928.14'},
#  {'data_internacao': '2023-12-15',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '1634.04'},
#  {'data_internacao': '2024-08-09',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '8663.41'},
#  {'data_internacao': '2023-11-01',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '4921.57'},
#  {'data_internacao': '2023-08-15',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '7503.08'},
#  {'data_internacao': '2024-09-19',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '1097.4'},
#  {'data_internacao': '2022-10-22',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '8850.54'},
#  {'data_internacao': '2024-07-31',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '4661.42'},
#  {'data_internacao': '2023-09-23',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '1925.48'},
#  {'data_internacao': '2024-05-29',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '1844.0'},
#  {'data_internacao': '2023-07-24',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '2910.68'},
#  {'data_internacao': '2023-02-04',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '4380.91'},
#  {'data_internacao': '2023-02-14',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '9262.49'},
#  {'data_internacao': '2024-08-30',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '7477.05'},
#  {'data_internacao': '2023-08-23',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '3909.58'},
#  {'data_internacao': '2023-08-23',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1181.58'},
#  {'data_internacao': '2023-05-25',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '2145.14'},
#  {'data_internacao': '2024-05-23',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '5953.08'},
#  {'data_internacao': '2024-05-09',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '5678.73'},
#  {'data_internacao': '2024-06-08',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '9842.31'},
#  {'data_internacao': '2024-06-16',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '1794.84'},
#  {'data_internacao': '2023-02-20',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '8725.52'},
#  {'data_internacao': '2024-09-12',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '7281.57'},
#  {'data_internacao': '2023-05-09',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '7726.87'},
#  {'data_internacao': '2023-03-12',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '4259.01'},
#  {'data_internacao': '2022-10-07',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '2467.32'},
#  {'data_internacao': '2024-03-18',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '5862.03'},
#  {'data_internacao': '2023-02-06',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '822.05'},
#  {'data_internacao': '2023-08-10',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '653.02'},
#  {'data_internacao': '2023-10-23',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '8146.98'},
#  {'data_internacao': '2023-12-01',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '2300.54'},
#  {'data_internacao': '2023-04-14',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '3884.51'},
#  {'data_internacao': '2022-12-24',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '1423.21'},
#  {'data_internacao': '2024-04-14',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '9704.57'},
#  {'data_internacao': '2023-12-09',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '6431.42'},
#  {'data_internacao': '2024-07-15',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '1823.59'},
#  {'data_internacao': '2023-04-23',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '6188.66'},
#  {'data_internacao': '2022-11-27',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '7933.38'},
#  {'data_internacao': '2024-07-22',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '8609.53'},
#  {'data_internacao': '2024-02-25',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '5280.63'},
#  {'data_internacao': '2022-12-03',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '8369.74'},
#  {'data_internacao': '2024-04-30',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '2072.58'},
#  {'data_internacao': '2023-04-19',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '1046.19'},
#  {'data_internacao': '2023-02-05',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '2253.78'},
#  {'data_internacao': '2024-09-25',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '8435.1'},
#  {'data_internacao': '2023-01-24',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '2209.94'},
#  {'data_internacao': '2023-11-03',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '8811.97'},
#  {'data_internacao': '2023-10-04',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '4643.7'},
#  {'data_internacao': '2024-06-23',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '9630.61'},
#  {'data_internacao': '2023-11-01',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '8510.31'},
#  {'data_internacao': '2024-02-11',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '3341.36'},
#  {'data_internacao': '2024-08-11',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '4258.1'},
#  {'data_internacao': '2023-03-18',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '3931.37'},
#  {'data_internacao': '2024-07-15',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '9645.47'},
#  {'data_internacao': '2024-03-13',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '2504.07'},
#  {'data_internacao': '2023-11-19',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '7077.15'},
#  {'data_internacao': '2023-03-15',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '2077.58'},
#  {'data_internacao': '2023-07-15',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '8408.42'},
#  {'data_internacao': '2024-03-08',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '2685.96'},
#  {'data_internacao': '2024-04-23',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '6416.19'},
#  {'data_internacao': '2024-09-13',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '3306.48'},
#  {'data_internacao': '2023-09-13',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '9323.21'},
#  {'data_internacao': '2023-03-27',
#   'tratamento': 't',
#   'dias_internacao': '21',
#   'custo_total': '2543.27'},
#  {'data_internacao': '2024-01-15',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '1765.91'},
#  {'data_internacao': '2024-07-23',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '1103.38'},
#  {'data_internacao': '2023-10-14',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '4339.59'},
#  {'data_internacao': '2023-11-14',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '3677.45'},
#  {'data_internacao': '2023-06-08',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '1078.03'},
#  {'data_internacao': '2024-03-20',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '3074.22'},
#  {'data_internacao': '2023-05-14',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '6713.5'},
#  {'data_internacao': '2023-07-13',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '680.71'},
#  {'data_internacao': '2024-01-25',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '5037.96'},
#  {'data_internacao': '2023-09-25',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '9582.46'},
#  {'data_internacao': '2023-02-17',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '6932.35'},
#  {'data_internacao': '2024-09-05',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '1307.61'},
#  {'data_internacao': '2023-01-20',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '1526.18'},
#  {'data_internacao': '2024-07-06',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '344.97'},
#  {'data_internacao': '2023-06-25',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '6049.29'},
#  {'data_internacao': '2024-08-07',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '7852.96'},
#  {'data_internacao': '2024-08-15',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '1437.46'},
#  {'data_internacao': '2024-07-30',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '6813.37'},
#  {'data_internacao': '2022-11-25',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '3658.46'},
#  {'data_internacao': '2022-12-01',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '8046.65'},
#  {'data_internacao': '2024-07-31',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '7594.85'},
#  {'data_internacao': '2024-05-27',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '611.42'},
#  {'data_internacao': '2023-05-02',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '7330.66'},
#  {'data_internacao': '2022-11-14',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '2376.89'},
#  {'data_internacao': '2023-02-12',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '4033.48'},
#  {'data_internacao': '2024-01-20',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '870.6'},
#  {'data_internacao': '2023-08-23',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '1395.55'},
#  {'data_internacao': '2024-05-15',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '9270.39'},
#  {'data_internacao': '2023-02-10',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '7041.79'},
#  {'data_internacao': '2024-02-24',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '7881.41'},
#  {'data_internacao': '2024-07-23',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '887.87'},
#  {'data_internacao': '2024-02-13',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '7252.98'},
#  {'data_internacao': '2023-02-23',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '430.88'},
#  {'data_internacao': '2024-03-10',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '391.85'},
#  {'data_internacao': '2023-11-23',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '7779.18'},
#  {'data_internacao': '2024-02-03',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '7216.96'},
#  {'data_internacao': '2023-11-14',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '5667.48'},
#  {'data_internacao': '2024-01-22',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5524.38'},
#  {'data_internacao': '2023-10-06',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '4639.31'},
#  {'data_internacao': '2024-03-07',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '5617.55'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '7901.1'},
#  {'data_internacao': '2023-07-25',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '2847.03'},
#  {'data_internacao': '2024-02-11',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '797.14'},
#  {'data_internacao': '2024-02-20',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1149.52'},
#  {'data_internacao': '2022-11-16',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '1577.61'},
# ...
#   'custo_total': '3199.15'},
#  {'data_internacao': '2024-04-27',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '5215.65'},
#  {'data_internacao': '2023-12-07',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '4155.19'},
#  {'data_internacao': '2024-08-22',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '136.43'},
#  {'data_internacao': '2024-05-02',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '9016.74'},
#  {'data_internacao': '2023-11-11',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5238.29'},
#  {'data_internacao': '2023-01-05',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '1494.71'},
#  {'data_internacao': '2024-02-29',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '5183.98'},
#  {'data_internacao': '2023-04-23',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '5417.47'},
#  {'data_internacao': '2022-10-23',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '582.31'},
#  {'data_internacao': '2023-07-30',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '3413.01'},
#  {'data_internacao': '2023-11-03',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '4435.48'},
#  {'data_internacao': '2024-06-09',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '7961.32'},
#  {'data_internacao': '2024-09-18',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '4918.87'},
#  {'data_internacao': '2023-12-03',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '6146.83'},
#  {'data_internacao': '2023-08-18',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '2998.73'},
#  {'data_internacao': '2024-06-08',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '3233.48'},
#  {'data_internacao': '2024-05-04',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '9476.49'},
#  {'data_internacao': '2023-09-20',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '5216.84'},
#  {'data_internacao': '2023-04-19',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4264.96'},
#  {'data_internacao': '2023-05-30',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '7843.59'},
#  {'data_internacao': '2024-06-25',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '7353.06'},
#  {'data_internacao': '2024-06-23',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '7766.59'},
#  {'data_internacao': '2024-03-03',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '267.29'},
#  {'data_internacao': '2024-07-04',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '7703.0'},
#  {'data_internacao': '2024-08-14',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '6612.48'},
#  {'data_internacao': '2024-03-26',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '7339.88'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '5824.1'},
#  {'data_internacao': '2022-10-28',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '6091.16'},
#  {'data_internacao': '2024-01-06',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '5873.38'},
#  {'data_internacao': '2023-10-02',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '7459.95'},
#  {'data_internacao': '2023-08-26',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '3088.52'},
#  {'data_internacao': '2023-08-03',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '4726.21'},
#  {'data_internacao': '2024-07-08',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '9518.33'},
#  {'data_internacao': '2024-03-11',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '3109.14'},
#  {'data_internacao': '2022-12-01',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '4559.93'},
#  {'data_internacao': '2024-05-17',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '3953.35'},
#  {'data_internacao': '2023-05-01',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '9213.24'},
#  {'data_internacao': '2024-09-22',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '1457.66'},
#  {'data_internacao': '2023-09-05',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '3613.56'},
#  {'data_internacao': '2024-01-28',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '4344.08'},
#  {'data_internacao': '2023-05-05',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '3189.89'},
#  {'data_internacao': '2024-02-08',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '9283.26'},
#  {'data_internacao': '2023-05-07',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '3987.91'},
#  {'data_internacao': '2024-03-10',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '927.46'},
#  {'data_internacao': '2024-08-28',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '2115.59'},
#  {'data_internacao': '2024-03-08',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1172.06'},
#  {'data_internacao': '2024-08-20',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '8557.06'},
#  {'data_internacao': '2024-06-23',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '7549.75'},
#  {'data_internacao': '2023-11-01',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '3510.16'},
#  {'data_internacao': '2022-11-20',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '742.79'},
#  {'data_internacao': '2023-07-16',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '2173.4'},
#  {'data_internacao': '2024-07-11',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '2652.81'},
#  {'data_internacao': '2024-09-29',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '2303.85'},
#  {'data_internacao': '2023-07-25',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '1194.44'},
#  {'data_internacao': '2024-01-09',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '8882.05'},
#  {'data_internacao': '2024-07-10',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '934.52'},
#  {'data_internacao': '2022-12-19',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '444.14'},
#  {'data_internacao': '2024-06-25',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '2245.26'},
#  {'data_internacao': '2023-05-18',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '6848.82'},
#  {'data_internacao': '2023-03-17',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '4633.88'},
#  {'data_internacao': '2022-10-10',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '4594.27'},
#  {'data_internacao': '2023-01-21',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '5075.14'},
#  {'data_internacao': '2023-03-06',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '3209.86'},
#  {'data_internacao': '2024-08-31',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '3632.08'},
#  {'data_internacao': '2023-07-11',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '1962.05'},
#  {'data_internacao': '2024-09-27',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '9329.4'},
#  {'data_internacao': '2023-11-21',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '4855.38'},
#  {'data_internacao': '2024-06-05',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '8576.76'},
#  {'data_internacao': '2023-06-19',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '7993.3'},
#  {'data_internacao': '2024-09-16',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '3497.17'},
#  {'data_internacao': '2023-06-27',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '256.25'},
#  {'data_internacao': '2024-05-30',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '5463.14'},
#  {'data_internacao': '2024-08-09',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '4778.45'},
#  {'data_internacao': '2022-11-23',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '6214.94'},
#  {'data_internacao': '2024-03-24',
#   'tratamento': 't',
#   'dias_internacao': '29',
#   'custo_total': '742.78'},
#  {'data_internacao': '2023-05-05',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '5098.14'},
#  {'data_internacao': '2024-09-15',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '7077.46'},
#  {'data_internacao': '2023-05-10',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '3627.6'},
#  {'data_internacao': '2023-07-08',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '1835.86'},
#  {'data_internacao': '2022-11-12',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '1697.17'},
#  {'data_internacao': '2022-10-31',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '883.78'},
#  {'data_internacao': '2023-10-10',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '3132.65'},
#  {'data_internacao': '2024-03-18',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '3710.96'},
#  {'data_internacao': '2022-12-22',
#   'tratamento': 't',
#   'dias_internacao': '19',
#   'custo_total': '8443.69'},
#  {'data_internacao': '2022-11-19',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '2128.63'},
#  {'data_internacao': '2022-11-21',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '2664.4'},
#  {'data_internacao': '2022-12-07',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '6952.08'},
#  {'data_internacao': '2024-01-11',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '4978.16'},
#  {'data_internacao': '2024-08-08',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '3148.67'},
#  {'data_internacao': '2023-12-30',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '6729.24'},
#  {'data_internacao': '2023-02-17',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '7063.07'},
#  {'data_internacao': '2022-11-16',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '312.76'},
#  {'data_internacao': '2023-12-04',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '3622.84'},
#  {'data_internacao': '2024-05-04',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '342.19'},
#  {'data_internacao': '2024-08-30',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '1690.6'},
#  {'data_internacao': '2023-01-01',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '7131.8'},
#  {'data_internacao': '2023-08-10',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '1769.37'},
#  {'data_internacao': '2023-07-10',
#   'tratamento': 't',
#   'dias_internacao': '15',
#   'custo_total': '6397.93'},
#  {'data_internacao': '2024-08-25',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '1093.29'},
#  {'data_internacao': '2023-05-25',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '9335.45'},
#  {'data_internacao': '2023-07-22',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '5702.4'},
#  {'data_internacao': '2022-12-10',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '7580.69'},
#  {'data_internacao': '2023-02-07',
#   'tratamento': 't',
#   'dias_internacao': '7',
#   'custo_total': '8933.09'},
#  {'data_internacao': '2023-05-04',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '2276.45'},
#  {'data_internacao': '2024-06-30',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '3094.73'},
#  {'data_internacao': '2023-08-04',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '7549.02'},
#  {'data_internacao': '2023-08-26',
#   'tratamento': 't',
#   'dias_internacao': '17',
#   'custo_total': '2919.89'},
#  {'data_internacao': '2022-11-24',
#   'tratamento': 't',
#   'dias_internacao': '14',
#   'custo_total': '8494.89'},
#  {'data_internacao': '2023-11-28',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '7415.91'},
#  {'data_internacao': '2024-04-20',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '5407.24'},
#  {'data_internacao': '2023-03-01',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '8012.37'},
#  {'data_internacao': '2023-12-25',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '5807.75'},
#  {'data_internacao': '2023-09-01',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '7679.07'},
#  {'data_internacao': '2022-11-15',
#   'tratamento': 't',
#   'dias_internacao': '27',
#   'custo_total': '136.57'},
#  {'data_internacao': '2023-03-01',
#   'tratamento': 't',
#   'dias_internacao': '8',
#   'custo_total': '5375.09'},
#  {'data_internacao': '2023-11-28',
#   'tratamento': 't',
#   'dias_internacao': '23',
#   'custo_total': '5260.19'},
#  {'data_internacao': '2024-07-27',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '2379.89'},
#  {'data_internacao': '2023-02-01',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '1617.41'},
#  {'data_internacao': '2023-12-08',
#   'tratamento': 't',
#   'dias_internacao': '18',
#   'custo_total': '9517.25'},
#  {'data_internacao': '2023-12-10',
#   'tratamento': 't',
#   'dias_internacao': '10',
#   'custo_total': '7814.93'},
#  {'data_internacao': '2024-01-16',
#   'tratamento': 't',
#   'dias_internacao': '24',
#   'custo_total': '2897.03'},
#  {'data_internacao': '2024-01-11',
#   'tratamento': 't',
#   'dias_internacao': '16',
#   'custo_total': '9575.35'},
#  {'data_internacao': '2024-09-15',
#   'tratamento': 't',
#   'dias_internacao': '6',
#   'custo_total': '5457.84'},
#  {'data_internacao': '2023-01-25',
#   'tratamento': 't',
#   'dias_internacao': '4',
#   'custo_total': '1750.78'},
#  {'data_internacao': '2024-08-10',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '2914.62'},
#  {'data_internacao': '2022-12-08',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '5738.92'},
#  {'data_internacao': '2023-04-20',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '5521.6'},
#  {'data_internacao': '2024-01-20',
#   'tratamento': 't',
#   'dias_internacao': '2',
#   'custo_total': '9621.67'},
#  {'data_internacao': '2023-08-10',
#   'tratamento': 't',
#   'dias_internacao': '9',
#   'custo_total': '7999.62'},
#  {'data_internacao': '2022-11-01',
#   'tratamento': 't',
#   'dias_internacao': '28',
#   'custo_total': '5168.26'},
#  {'data_internacao': '2024-05-28',
#   'tratamento': 't',
#   'dias_internacao': '3',
#   'custo_total': '1679.39'},
#  {'data_internacao': '2023-08-30',
#   'tratamento': 't',
#   'dias_internacao': '11',
#   'custo_total': '3129.42'},
#  {'data_internacao': '2022-12-16',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '5190.15'},
#  {'data_internacao': '2022-10-23',
#   'tratamento': 't',
#   'dias_internacao': '5',
#   'custo_total': '9095.21'},
#  {'data_internacao': '2024-06-15',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '1305.39'},
#  {'data_internacao': '2023-03-13',
#   'tratamento': 't',
#   'dias_internacao': '20',
#   'custo_total': '4131.47'},
#  {'data_internacao': '2023-01-08',
#   'tratamento': 't',
#   'dias_internacao': '22',
#   'custo_total': '8294.45'},
#  {'data_internacao': '2023-09-20',
#   'tratamento': 't',
#   'dias_internacao': '13',
#   'custo_total': '5929.29'},
#  {'data_internacao': '2024-09-06',
#   'tratamento': 't',
#   'dias_internacao': '12',
#   'custo_total': '2482.74'},
#  {'data_internacao': '2023-02-28',
#   'tratamento': 't',
#   'dias_internacao': '1',
#   'custo_total': '3166.47'},
#  {'data_internacao': '2024-06-11',
#   'tratamento': 't',
#   'dias_internacao': '26',
#   'custo_total': '8923.05'},
#  {'data_internacao': '2023-08-08',
#   'tratamento': 't',
#   'dias_internacao': '25',
#   'custo_total': '7889.94'},
#  {'data_internacao': '2024-01-10',
#   'tratamento': 't',
#   'dias_internacao': '30',
#   'custo_total': '9492.76'},
#  ...]
