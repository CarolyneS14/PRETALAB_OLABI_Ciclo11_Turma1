# %% [markdown]
# # Aula 1: Introdução ao Manuseio de Arquivos em Python

# %% [markdown]
# ###Preparando o ambiente

# %%
# Montando o Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls
# Out:
# drive  sample_data

# %%
# mostra o conteudo do drive
# !ls /content/drive/MyDrive/
# Out:
# 'Apresentação - Hipóteses .gslides'
# 'Carolyne Oliveira'
#  Certificados
#  Classroom
# 'Colab Notebooks'
# 'Cópia de Exercicio-Segunda.gsheet'
#  COURSERA
#  CURRICULUM
#  DESENVOLVE
# 'Desenvolve 2024.gsheet'
# 'experimento_duraccao (1).gsheet'
#  experimento_duraccao.gsheet
#  grande_arquivo.gsheet
# 'Grupo 03- Desenvolve Boticário 2024.gjam'
# 'Jam sem título.gjam'
#  LABORATORIA
#  PRETALAB
# 'Pretalab | Ciclo 11 | Oficina de Seleção Tarde | Carolyne Santos de Oliveira.ipynb'
#  REPROGRAMA
#  UDEMY

# %%
# direciona para o caminho desejado
# %cd /content/drive/MyDrive/PRETALAB/
# Out:
# /content/drive/MyDrive/PRETALAB

# %%
#Este módulo fornece uma maneira simples de usar funcionalidades que são dependentes de sistema operacional
import os

# os.getcwd() retorna o caminho absoluto do diretório de trabalho atual
print(os.getcwd())
# Out:
# /content/drive/MyDrive/PRETALAB

# %%
# Mostra o conteudo do local/pasta
# !ls
# Out:
# 'Banco de Dados'  'Linkedin Github - Ciclo 11.gsheet'  'Projeto 1'   Python
