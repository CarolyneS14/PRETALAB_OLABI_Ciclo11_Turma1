# %% [markdown]
# # Estatística com Python - Probabilidade, Amostragem e Testes de Hipóteses

# %% [markdown]
# ## Aula 1: Introdução - Conceitos Básicos de Estatística em Python

# %% [markdown]
# ### Na aula de hoje:

# %% [markdown]
# #### Tópicos:

# %% [markdown]
# . Estatística Descritiva: Ferramentas para sumarizar e descrever dados.
#
# - Média, mediana, moda.
# - Desvio padrão e variância.
# - Quartis e percentis.

# %% [markdown]
# #### **Estatística Descritiva: Ferramentas para Sumarizar e Descrever Dados** 🎯

# %% [markdown]
# Se estatística fosse uma pessoa, ela seria aquele amigo que sabe transformar um monte de números em informações úteis. Estatística descritiva é exatamente isso: ela pega dados "crus" e transforma em insights mais simples, organizados e compreensíveis.
#
#
# 🎨 Por que isso importa?
#
# Imagine que você tem uma planilha cheia de notas de alunos, ou vendas de produtos, ou até resultados de um experimento. Antes de fazer qualquer análise complicada, você quer entender o que esses dados estão dizendo de forma simples. E para isso, usamos ferramentas da estatística descritiva!

# %%
#Biblioteca
import numpy as np

# %%
#Exemplo de conjunto de dados
dados = [12, 15, 12, 14, 16, 18, 19, 17, 14, 16]

# %%
dados
# Out:
# [12, 15, 12, 14, 16, 18, 19, 17, 14, 16]

# %% [markdown]
# ##### Medidas de Tendência Central: Onde seus dados tendem a "morar" 🏠
#
# Essas medidas são como tentar entender qual o "ponto de encontro" dos seus dados.

# %% [markdown]
# 👑**Média: O líder da equipe!**
#
# A **média** é aquele aluno que sempre "divide igual para todo mundo". Para calcular, você soma todos os valores e depois divide pelo número de observações.
#
# ![image.png](data:image/png;base64,...)

# %%
# Média
media = np.mean(dados)
media
# Out:
# 15.3

# %% [markdown]
# ✂️ **Mediana: O mestre do equilíbrio!**
#
#
# A mediana é o valor que está bem no meio dos dados ordenados. Se você colocar todos os números em ordem, ela é o valor que divide os dados em duas partes iguais.
#
# Como calcular:
#
# - Ordene os valores.
#
# - Se o número de observações for ímpar, a mediana é o valor do meio.
#
# - Se for par, a mediana é a média dos dois valores do meio.
#
# Exemplo:
#
# Para as notas [6, 7, 8, 9, 10], a mediana é 8, pois está no meio.
#
# Se tivermos [6, 7, 8, 9], a mediana será:
#
# ![image.png](data:image/png;base64,...)
#
#
# Mediana é aquela pessoa justa que divide igualmente as opiniões no grupo!

# %%
# Mediana
mediana = np.median(dados)
mediana
# Out:
# 15.5

# %% [markdown]
# 🔁 **Moda: A celebridade do grupo!**
#
# A moda é o valor que mais se repete nos dados. Se a média representa o "líder" e a mediana o "justo", a moda é a pessoa mais popular.
#
# Exemplo:
# Se temos as notas [6, 7, 7, 8, 9], a moda é **7**, porque aparece duas vezes. Se não houver repetições, dizemos que não há moda.

# %%
# Moda
from scipy import stats
moda = stats.mode(dados)
moda
# Out:
# ModeResult(mode=12, count=2)

# %% [markdown]
# ##### Medidas de Dispersão: Quão "espalhados" estão seus dados? 🌪️
#
# Agora que você já sabe onde seus dados tendem a estar (média, mediana, moda), é hora de entender como eles estão espalhados. É aqui que entram as medidas de dispersão.

# %% [markdown]
# 📏 **Variância: Quanto seus dados "variam"?**
#
# A variância mede o quão longe os dados estão da média. Ou seja, ela responde à pergunta: os dados estão perto ou longe da média?
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exemplo: Imagine que as notas são [6, 7, 8, 9, 10]. A média é 8, então calculamos o quanto cada nota se afasta da média:
#
#
# (6-8)
# 2
# =
# 4
# ,
# (7-8)
# 2
# =
# 1
# ,
# (8-8)
# 2
# =
# 0
# ,
# (9-8)
# 2
# =
# 1
# ,
# (10-8)
# 2
# =
# 4
# (6-8)
# 2
#  =4,(7-8)
# 2
#  =1,(8-8)
# 2
#  =0,(9-8)
# 2
#  =1,(10-8)
# 2
#  =4
#
#
# A variância seria a média desses valores.
#
# Se a variância é grande, significa que os dados estão bem espalhados. Se é pequena, estão mais "juntinhos".

# %%
# Variância
variancia = np.var(dados)
variancia
# Out:
# 5.01

# %% [markdown]
# 🧮 **Desvio Padrão: A distância típica da média **🚶‍♂️
#
# O desvio padrão é a raiz quadrada da variância. Ele representa a "distância típica" entre cada valor e a média.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exemplo: Se a variância das notas foi 2, então o desvio padrão será:
#
# ![image.png](data:image/png;base64,...)
#
#
# O desvio padrão é como medir o quanto as notas de um aluno "desviam" da média.

# %%
# Desvio Padrão
desvio_padrao = np.std(dados)
desvio_padrao
# Out:
# 2.238302928559939

# %%
print(f"A variância é: {variancia:.2f}, e o Desvio Padrão: {desvio_padrao:.2f}")
# Out:
# A variância é: 5.01, e o Desvio Padrão: 2.24

# %% [markdown]
# **Quartis e Percentis: Dividindo os dados em pedaços** 🍰
#
# Às vezes, você quer dividir seus dados em partes iguais. Quartis e percentis ajudam a fazer isso.
#
# Quartis: Dividem os dados em quatro partes iguais.
#
# - O primeiro quartil (Q1) marca o ponto onde estão os 25% dos menores valores.
#
# - O segundo quartil (Q2) é a mediana (50%).
#
# - O terceiro quartil (Q3) marca onde estão 75% dos menores valores.
#
# - Percentis: Dividem os dados em 100 partes. O percentil 90 significa que 90% dos dados estão abaixo desse valor.

# %%
# Quartil
primeiro_quartil = np.percentile(dados, 25)
segundo_quartil = np.percentile(dados, 50) #mediana
terceiro_quartil = np.percentile(dados, 75)

print(f"Primeiro quartil (25%): {primeiro_quartil}")
print(f"Segundo quartil (50%): {segundo_quartil}")
print(f"Terceiro quartil (75%): {terceiro_quartil}")
# Out:
# Primeiro quartil (25%): 14.0
# Segundo quartil (50%): 15.5
# Terceiro quartil (75%): 16.75

# %% [markdown]
# #### Resumo para ficar na memória:

# %% [markdown]
# | Conceito                     | Definição Simples                                | Exemplo        |
# |-------------------------------|-------------------------------------------------|----------------|
# | **Média**                     | Soma dos valores dividida pelo número de observações | Média das notas = 8 |
# | **Mediana**                   | Valor que divide os dados ao meio               | Notas: 7,5     |
# | **Moda**                      | Valor mais frequente                            | Nota 7         |
# | **Variância**                 | Mede o quão longe os valores estão da média      | Maior variância = maior espalhamento |
# | **Desvio Padrão**             | Raiz quadrada da variância                      | 1,41           |
# | **Quartis e Percentis**       | Dividem os dados em partes iguais

# %% [markdown]
# ### Prática

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Gerando o DataFrame fictício de vendas
np.random.seed(42)

# %%
# Parâmetros
n = 5000 # criando a quantidade de linhas do meu df
vendedores = [f"Vendedor {i}" for i in range (1, 21)] #quantidade de vendedores
produtos = [f"Produto {i}" for i in range (1, 11)] #quantidade de produtos
regioes = ['Sul', 'Sudeste', 'Norte', 'Centro-Oeste', 'Nordeste']

# %%
# Gerando os Dados
data = pd.DataFrame({
    'vendedor': np.random.choice(vendedores, size=n),
    'produto': np.random.choice(produtos, size=n),
    'regiao': np.random.choice(regioes, size=n),
    'quantidade': np.random.randint(1, 50, size=n),
    'valor_unitario': np.round(np.random.uniform(10, 100, size=n), 2),
    'data_venda': pd.date_range('2023-01-01', periods=n, freq='h').strftime('%Y-%m-%d')
})

# %%
#Visualizar df
data.head()
# Out:
#       vendedor    produto        regiao  quantidade  valor_unitario  \
# 0   Vendedor 6  Produto 9      Nordeste          20           44.50
# 1   Vendedor 6  Produto 7  Centro-Oeste          11           46.68
# 2  Vendedor 13  Produto 4         Norte          37           48.98
# 3   Vendedor 4  Produto 6      Nordeste          40           41.40
# 4   Vendedor 8  Produto 5  Centro-Oeste           4           72.92
#
#    data_venda
# 0  2023-01-01
# 1  2023-01-01
# 2  2023-01-01
# 3  2023-01-01
# 4  2023-01-01

# %%
# Visualizar colunas do df 'data'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vendedor        5000 non-null   object
#  1   produto         5000 non-null   object
#  2   regiao          5000 non-null   object
#  3   quantidade      5000 non-null   int64
#  4   valor_unitario  5000 non-null   float64
#  5   data_venda      5000 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 234.5+ KB

# %%
# Corrigindo o coluna de 'data_venda'
data['data_venda'] = pd.to_datetime(data['data_venda'])

# %%
# Visualizar colunas do df 'data'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vendedor        5000 non-null   object
#  1   produto         5000 non-null   object
#  2   regiao          5000 non-null   object
#  3   quantidade      5000 non-null   int64
#  4   valor_unitario  5000 non-null   float64
#  5   data_venda      5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 234.5+ KB

# %%
# Calculando o valor total
data['valor_total'] = data['quantidade'] * data['valor_unitario']

# %%
# Ver nova coluna
data.head()
# Out:
#       vendedor    produto        regiao  quantidade  valor_unitario  \
# 0   Vendedor 6  Produto 9      Nordeste          20           44.50
# 1   Vendedor 6  Produto 7  Centro-Oeste          11           46.68
# 2  Vendedor 13  Produto 4         Norte          37           48.98
# 3   Vendedor 4  Produto 6      Nordeste          40           41.40
# 4   Vendedor 8  Produto 5  Centro-Oeste           4           72.92
#
#   data_venda  valor_total
# 0 2023-01-01       890.00
# 1 2023-01-01       513.48
# 2 2023-01-01      1812.26
# 3 2023-01-01      1656.00
# 4 2023-01-01       291.68

# %% [markdown]
# - Estatísticas descritivas

# %%
# Média
media_valor_total = round(data['valor_total'].mean())
media_valor_total
# Out:
# 1367

# %%
# Mediana
mediana_valor_total = round(data['valor_total'].median())
mediana_valor_total
# Out:
# 1082

# %%
# Moda (numero que mais aparece na coluna)
moda_valor_total = data['valor_total'].mode()[0]
moda_valor_total
# Out:
# 23.7

# %%
# Variância
variancia_valor_total = round(data['valor_total'].var(), 2)
variancia_valor_total
# Out:
# 1170520.8727733307

# %%
# Desvio Padrão
desvio_padrao_valor_total = round(data['valor_total'].std(), 2)
desvio_padrao_valor_total
# Out:
# 1081.9061293722903

# %%
# Quartil
quartis_valor_total = data['valor_total'].quantile([0.25, 0.5, 0.75])
quartis_valor_total
# Out:
# 0.25     484.150
# 0.50    1081.520
# 0.75    2021.145
# Name: valor_total, dtype: float64

# %%
# Análise descritiva da coluna
round(data['valor_total'].describe(), 2)
# Out:
# count    5000.00
# mean     1367.19
# std      1081.91
# min        12.95
# 25%       484.15
# 50%      1081.52
# 75%      2021.14
# max      4832.38
# Name: valor_total, dtype: float64

# %%
# Filtro para ver o/os produto/s com o valor máximo do total de venda na coluna 'valor_total'
data[data['valor_total'] == data['valor_total'].max()]
# Out:
#          vendedor    produto        regiao  quantidade  valor_unitario  \
# 2839  Vendedor 20  Produto 3  Centro-Oeste          49           98.62
#
#      data_venda  valor_total
# 2839 2023-04-29      4832.38

# %%
# Filtro para verificar os produtos com o valor abaixo do primeiro quartil
data[data['valor_total'] < quartis_valor_total[0.25]]
# Out:
#          vendedor    produto        regiao  quantidade  valor_unitario  \
# 4      Vendedor 8  Produto 5  Centro-Oeste           4           72.92
# 8     Vendedor 11  Produto 9       Sudeste           8           36.83
# 9     Vendedor 20  Produto 9  Centro-Oeste          30           13.83
# 14     Vendedor 6  Produto 1           Sul           5           17.45
# 15     Vendedor 4  Produto 4         Norte           3           92.36
# ...           ...        ...           ...         ...             ...
# 4988  Vendedor 13  Produto 2           Sul          15           26.83
# 4991  Vendedor 14  Produto 9         Norte           8           23.39
# 4993   Vendedor 9  Produto 3      Nordeste           3           45.95
# 4994  Vendedor 12  Produto 1       Sudeste           9           39.22
# 4999  Vendedor 19  Produto 8         Norte           4           89.94
#
#      data_venda  valor_total
# 4    2023-01-01       291.68
# 8    2023-01-01       294.64
# ...

# %%
# Ou
# Filtro para verificar os produtos com o valor abaixo do primeiro quartil
data[data['valor_total'] <= 484.15]
# Out:
#          vendedor    produto        regiao  quantidade  valor_unitario  \
# 4      Vendedor 8  Produto 5  Centro-Oeste           4           72.92
# 8     Vendedor 11  Produto 9       Sudeste           8           36.83
# 9     Vendedor 20  Produto 9  Centro-Oeste          30           13.83
# 14     Vendedor 6  Produto 1           Sul           5           17.45
# 15     Vendedor 4  Produto 4         Norte           3           92.36
# ...           ...        ...           ...         ...             ...
# 4988  Vendedor 13  Produto 2           Sul          15           26.83
# 4991  Vendedor 14  Produto 9         Norte           8           23.39
# 4993   Vendedor 9  Produto 3      Nordeste           3           45.95
# 4994  Vendedor 12  Produto 1       Sudeste           9           39.22
# 4999  Vendedor 19  Produto 8         Norte           4           89.94
#
#      data_venda  valor_total
# 4    2023-01-01       291.68
# 8    2023-01-01       294.64
# ...

# %%
# Visualizações Histograma
plt.figure(figsize=(12, 6))
sns.histplot(data['valor_total'], kde=True, bins=30, color='blue')
plt.title('Distribuição dos Valores Totais de Venda')
plt.xlabel('Valor Total de Venda')
plt.ylabel('Frequência')
plt.show()

# %%
# Boxplot dos valores totais de venda por região
plt.figure(figsize=(10, 6))
sns.boxplot(x='regiao', y='valor_total', data=data, palette='Set3', hue='regiao')
plt.title('Boxplot dos Valores Totais de Venda por Região')
plt.xlabel('Região')
plt.ylabel('Valor Total de Venda')
plt.show()

# %%
# Gráfico de barras das quantidade vendidas por produtos
plt.figure(figsize=(12, 6))
sns.barplot(x='produto', y='quantidade', data=data, estimator=sum, palette='Set3', hue='produto')
plt.title('Total de Quantidade Vendida por Produto')
plt.xlabel('Produtos')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45)
plt.show()
